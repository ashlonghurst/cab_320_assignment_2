# %% [markdown]
# # CAB320 Assignment 2 - Transfer Learning
# Anthony Vanderkop, Thierry Peynot, Frederic Maire (Jupyter Notebook template: 2025)

# %% [markdown]
# Anthony Vanderkop, Thierry Peynot, Frederic Maire (Jupyter Notebook template: 2025)
#
# ## Instructions:
# The functions and classes defined in this module will be called by the marker without modification. You should complete the functions and classes according to their specified interfaces.
#
# No partial marks will be awarded for functions that do not meet the specifications of the interfaces.

# %%
### LIBRARY IMPORTS ###
import os
import numpy as np

import keras.applications as ka
import keras
import pandas as pd
import matplotlib.pyplot as plt
import os
import cv2
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support
import tensorflow as tf

# %% [markdown]
# ## Task 1
# Implement the my_team()function

# %%
def my_team():
    '''
    Return the list of the team members of this assignment submission as a list
    of triplet of the form (student_number, first_name, last_name)
    
    '''
    return [('n0827053', 'Ashley', 'Longhurst'), ('n9439960','Kyle', 'Ruter'), ('n12393631', 'Katherine', 'Newman')]

# %%
my_team()
# Out:
# [('n0827053', 'Ashley', 'Longhurst'),
#  ('n9439960', 'Kyle', 'Ruter'),
#  ('n12393631', 'Katherine', 'Newman')]

# %% [markdown]
# ## Task 2
# Download the small_flower_dataset from Canvas and load the data

# %%
def load_data(path):
    '''
    Load in the dataset from its home path. Path should be a string of the path
    to the home directory the dataset is found in. Should return a numpy array
    with paired images and class labels.
    
    Insert a more detailed description here.
    '''
    subfolders = ['daisy', 'dandelion', 'roses', 'tulips', 'sunflowers']
    
    images = []
    labels = []
    
    label_map = {
        'daisy': 0,
        'dandelion': 1,
        'roses': 2,
        'tulips': 3,
        'sunflowers': 4
    }

    # Load the images
    for subfolder in subfolders:
        full_path = os.path.join(path, subfolder)   # uses the argument now
        image_files = os.listdir(full_path)
    
        for img_file in image_files:
            img_path = os.path.join(full_path, img_file)
            img = cv2.imread(img_path)
    
            if img is not None:
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                img = cv2.resize(img, (128, 128))
                images.append(img)
                labels.append(label_map[subfolder])
    
    X = np.array(images)
    y = np.array(labels)
    
    print("All images shape:", X.shape)
    print("All labels shape:", y.shape)
    print("Class labels:", label_map)
    dataset = np.array(list(zip(X, y)), dtype=object)
    return dataset

# %%
dataset = load_data('./small_flower_dataset')
X = np.array([item[0] for item in dataset])
Y = np.array([item[1] for item in dataset])
# Out:
# All images shape: (1000, 128, 128, 3)
# All labels shape: (1000,)
# Class labels: {'daisy': 0, 'dandelion': 1, 'roses': 2, 'tulips': 3, 'sunflowers': 4}

# %%
"""
We want to have a look at how the images are set up
"""

print((X[0][0][:5])) # The first row of pixels just to look at the values 0 - 255. Each pixel RGB values
print(len(X[0][0])) # 128 - First row has 128. So all looks ok.
# Out:
# [[ 26  39  17]
#  [ 61  64  79]
#  [239 242 248]
#  [238 245 251]
#  [238 245 253]]
# 128

# %%
"""
A quick check to see how the data is structured and to see if
class labels a fairly balanced. This code block wont be imcluded in the final submission.
"""
print(np.unique(Y, return_counts=True)) # We can see there are 200 of each
# Out:
# (array([0, 1, 2, 3, 4]), array([200, 200, 200, 200, 200]))

# %%
"""
This code block is just to see the load has worked
and to see if the labels and the images are matched.
It probably wont be included in the final submission
"""

label_map_check = {
    0: 'daisy',
    1: 'dandelion',
    2: 'roses',
    3: 'tulips',
    4: 'sunflowers'
}

plt.figure(figsize=(12, 4))

for flower_label in range(5):
    for i in range(len(dataset)):
        image = dataset[i][0]
        label = dataset[i][1]

        if label == flower_label:
            plt.subplot(1, 5, flower_label + 1)
            plt.imshow(image)
            plt.title(f"{label}: {label_map_check[label]}")
            plt.axis('off')
            break

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 3
# Prepare your training, validation and test sets for the non-accelerated version of transfer learning.

# %%
def split_data(X, Y, train_fraction, randomize=False, eval_set=True):
    """
    Split the data into training and testing sets. If eval_set is True, also create
    an evaluation dataset. There should be two outputs if eval_set there should
    be three outputs (train, test, eval), otherwise two outputs (train, test).
    
    To see what type train, test, and eval should be, refer to the inputs of 
    transfer_learning().
    
    This uses sklearn's train test split library. See https://scikit-learn.org/stable/modules/generated/
    sklearn.model_selection.train_test_split.html. The output type conforms to the transfer_learning()
    input data type (a tuple of images and labels : eg (images, labesl)). Random state is utilised for reproducability
    initially among team members and the randomise is used to ensure no class imbalance.
    """
    if eval_set:
        # First split: training set and leftover set
        X_train, X_temp, Y_train, Y_temp = train_test_split(
            X,
            Y,
            train_size=train_fraction,
            shuffle=True,
            stratify=Y,
            random_state=42
        )

        # Second split: split leftover data equally into test and eval sets
        X_test, X_eval, Y_test, Y_eval = train_test_split(
            X_temp,
            Y_temp,
            test_size=0.5,
            shuffle=True,
            stratify=Y_temp,
            random_state=42
        )

        train = (X_train, Y_train)
        test = (X_test, Y_test)
        eval_data = (X_eval, Y_eval)

        return train, test, eval_data

    else:
        X_train, X_test, Y_train, Y_test = train_test_split(
            X,
            Y,
            train_size=train_fraction,
            shuffle=True,
            stratify=Y,
            random_state=42
        )

        train = (X_train, Y_train)
        test = (X_test, Y_test)

        return train, test

# %%
def get_sets(X, Y, train_ratio=0.8, randomize=True, use_eval=True):
    '''
    Split data into train/test sets, with an optional evaluation set.
    '''
    if use_eval:
        train_set, test_set, eval_set = split_data(
            X, Y, train_ratio, randomize=randomize, eval_set=True
        )
    else:
        train_set, test_set = split_data(
            X, Y, train_ratio, randomize=randomize, eval_set=False
        )
        eval_set = None
    return train_set, test_set, eval_set

# %%
train_set, test_set, eval_set = get_sets(X, Y, train_ratio=0.8, randomize=True, use_eval=True)

# %%
"""
Plots to show how the train test split function worked 
and if any class imbalance exists in the sets. This can be talked
about in the text block below later on. 
"""
def plot_class_distributions(train_set, test_set, eval_set=None, label_map=None):
 
    sets = [('Training Set', train_set[1]), ('Testing Set', test_set[1])]
    if eval_set is not None:
        sets.append(('Evaluation Set', eval_set[1]))

    n = len(sets)
    fig, axes = plt.subplots(1, n, figsize=(5 * n, 4))

    if n == 1:
        axes = [axes]

    for ax, (title, y) in zip(axes, sets):
        unique, counts = np.unique(y, return_counts=True)
        names = [label_map[i] for i in unique] if label_map else unique
        ax.bar(names, counts)
        ax.set_title(f'{title} (n={len(y)})')
        ax.set_ylabel('Count')
        ax.tick_params(axis='x', rotation=45)

    plt.tight_layout()
    plt.show()

# %%
plot_class_distributions(train_set, test_set, eval_set, label_map=label_map_check)

# %% [markdown]
# Report: Include details of how you have split the data to perform this training. Ensure the split is reasonable and does not introduce class imbalance during training

# %% [markdown]
# The dataset was divided into training, testing, and evaluation sets using a two step process with scikit-learn's train test split function. 80% of the data was allocated to the training set, with the remaining 20% further divided into a 10% test set and a 10% evaluation set. Stratification was applied at both stages to ensure the proportional representation of each class is preserved across all splits to avoid class imbalance. A fixed random state was used throughout for reproducibility across team members. Because the training set is large (n=800), the class counts remain even when stratified. The test and evaluation sets (n=100 each) contain 20 samples per class, ensuring even class representation. The above plots show no class imbalance.

# %% [markdown]
# ## Task 4
# Using the tf.keras.applications module download a pretrained MobileNetV2 network.

# %%
def load_model():
    '''
    Load in a model using the tf.keras.applications model and return it.
    Insert a more detailed description here
    '''
    model = tf.keras.applications.MobileNetV2(
    weights='imagenet'
    )

    return model

# %%
model = load_model()
model.summary()
# Out:
# Model: "mobilenetv2_1.00_224"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 112, 112,  │        864 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_Conv1            │ (None, 112, 112,  │        128 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1_relu (ReLU)   │ (None, 112, 112,  │          0 │ bn_Conv1[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │        288 │ Conv1_relu[0][0]  │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │        128 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │          0 │ expanded_conv_de… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 112, 112,  │        512 │ expanded_conv_de… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 112, 112,  │         64 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand      │ (None, 112, 112,  │      1,536 │ expanded_conv_pr… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_BN   │ (None, 112, 112,  │        384 │ block_1_expand[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_relu │ (None, 112, 112,  │          0 │ block_1_expand_B… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_pad         │ (None, 113, 113,  │          0 │ block_1_expand_r… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise   │ (None, 56, 56,    │        864 │ block_1_pad[0][0] │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 56, 56,    │        384 │ block_1_depthwis… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 56, 56,    │          0 │ block_1_depthwis… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project     │ (None, 56, 56,    │      2,304 │ block_1_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project_BN  │ (None, 56, 56,    │         96 │ block_1_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand      │ (None, 56, 56,    │      3,456 │ block_1_project_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_BN   │ (None, 56, 56,    │        576 │ block_2_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_relu │ (None, 56, 56,    │          0 │ block_2_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise   │ (None, 56, 56,    │      1,296 │ block_2_expand_r… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 56, 56,    │        576 │ block_2_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 56, 56,    │          0 │ block_2_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project     │ (None, 56, 56,    │      3,456 │ block_2_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project_BN  │ (None, 56, 56,    │         96 │ block_2_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_add (Add)   │ (None, 56, 56,    │          0 │ block_1_project_… │
# │                     │ 24)               │            │ block_2_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand      │ (None, 56, 56,    │      3,456 │ block_2_add[0][0] │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_BN   │ (None, 56, 56,    │        576 │ block_3_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_relu │ (None, 56, 56,    │          0 │ block_3_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_pad         │ (None, 57, 57,    │          0 │ block_3_expand_r… │
# │ (ZeroPadding2D)     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise   │ (None, 28, 28,    │      1,296 │ block_3_pad[0][0] │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 28, 28,    │        576 │ block_3_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 28, 28,    │          0 │ block_3_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project     │ (None, 28, 28,    │      4,608 │ block_3_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project_BN  │ (None, 28, 28,    │        128 │ block_3_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand      │ (None, 28, 28,    │      6,144 │ block_3_project_… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_BN   │ (None, 28, 28,    │        768 │ block_4_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_relu │ (None, 28, 28,    │          0 │ block_4_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise   │ (None, 28, 28,    │      1,728 │ block_4_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 28, 28,    │        768 │ block_4_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 28, 28,    │          0 │ block_4_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project     │ (None, 28, 28,    │      6,144 │ block_4_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project_BN  │ (None, 28, 28,    │        128 │ block_4_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_add (Add)   │ (None, 28, 28,    │          0 │ block_3_project_… │
# │                     │ 32)               │            │ block_4_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand      │ (None, 28, 28,    │      6,144 │ block_4_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_BN   │ (None, 28, 28,    │        768 │ block_5_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_relu │ (None, 28, 28,    │          0 │ block_5_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise   │ (None, 28, 28,    │      1,728 │ block_5_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 28, 28,    │        768 │ block_5_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 28, 28,    │          0 │ block_5_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project     │ (None, 28, 28,    │      6,144 │ block_5_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project_BN  │ (None, 28, 28,    │        128 │ block_5_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_add (Add)   │ (None, 28, 28,    │          0 │ block_4_add[0][0… │
# │                     │ 32)               │            │ block_5_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand      │ (None, 28, 28,    │      6,144 │ block_5_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_BN   │ (None, 28, 28,    │        768 │ block_6_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_relu │ (None, 28, 28,    │          0 │ block_6_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_pad         │ (None, 29, 29,    │          0 │ block_6_expand_r… │
# │ (ZeroPadding2D)     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise   │ (None, 14, 14,    │      1,728 │ block_6_pad[0][0] │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 14, 14,    │        768 │ block_6_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 14, 14,    │          0 │ block_6_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project     │ (None, 14, 14,    │     12,288 │ block_6_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project_BN  │ (None, 14, 14,    │        256 │ block_6_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand      │ (None, 14, 14,    │     24,576 │ block_6_project_… │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_BN   │ (None, 14, 14,    │      1,536 │ block_7_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_relu │ (None, 14, 14,    │          0 │ block_7_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise   │ (None, 14, 14,    │      3,456 │ block_7_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 14, 14,    │      1,536 │ block_7_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 14, 14,    │          0 │ block_7_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project     │ (None, 14, 14,    │     24,576 │ block_7_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project_BN  │ (None, 14, 14,    │        256 │ block_7_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_add (Add)   │ (None, 14, 14,    │          0 │ block_6_project_… │
# │                     │ 64)               │            │ block_7_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand      │ (None, 14, 14,    │     24,576 │ block_7_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_BN   │ (None, 14, 14,    │      1,536 │ block_8_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_relu │ (None, 14, 14,    │          0 │ block_8_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise   │ (None, 14, 14,    │      3,456 │ block_8_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 14, 14,    │      1,536 │ block_8_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 14, 14,    │          0 │ block_8_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project     │ (None, 14, 14,    │     24,576 │ block_8_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project_BN  │ (None, 14, 14,    │        256 │ block_8_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_add (Add)   │ (None, 14, 14,    │          0 │ block_7_add[0][0… │
# │                     │ 64)               │            │ block_8_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand      │ (None, 14, 14,    │     24,576 │ block_8_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_BN   │ (None, 14, 14,    │      1,536 │ block_9_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_relu │ (None, 14, 14,    │          0 │ block_9_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise   │ (None, 14, 14,    │      3,456 │ block_9_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 14, 14,    │      1,536 │ block_9_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 14, 14,    │          0 │ block_9_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project     │ (None, 14, 14,    │     24,576 │ block_9_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project_BN  │ (None, 14, 14,    │        256 │ block_9_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_add (Add)   │ (None, 14, 14,    │          0 │ block_8_add[0][0… │
# │                     │ 64)               │            │ block_9_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand     │ (None, 14, 14,    │     24,576 │ block_9_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_BN  │ (None, 14, 14,    │      1,536 │ block_10_expand[… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_re… │ (None, 14, 14,    │          0 │ block_10_expand_… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise  │ (None, 14, 14,    │      3,456 │ block_10_expand_… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 14, 14,    │      1,536 │ block_10_depthwi… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 14, 14,    │          0 │ block_10_depthwi… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project    │ (None, 14, 14,    │     36,864 │ block_10_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project_BN │ (None, 14, 14,    │        384 │ block_10_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand     │ (None, 14, 14,    │     55,296 │ block_10_project… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_BN  │ (None, 14, 14,    │      2,304 │ block_11_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_re… │ (None, 14, 14,    │          0 │ block_11_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise  │ (None, 14, 14,    │      5,184 │ block_11_expand_… │
# │ (DepthwiseConv2D)   │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 14, 14,    │      2,304 │ block_11_depthwi… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 14, 14,    │          0 │ block_11_depthwi… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project    │ (None, 14, 14,    │     55,296 │ block_11_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project_BN │ (None, 14, 14,    │        384 │ block_11_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_add (Add)  │ (None, 14, 14,    │          0 │ block_10_project… │
# │                     │ 96)               │            │ block_11_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand     │ (None, 14, 14,    │     55,296 │ block_11_add[0][… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_BN  │ (None, 14, 14,    │      2,304 │ block_12_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_re… │ (None, 14, 14,    │          0 │ block_12_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise  │ (None, 14, 14,    │      5,184 │ block_12_expand_… │
# │ (DepthwiseConv2D)   │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 14, 14,    │      2,304 │ block_12_depthwi… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 14, 14,    │          0 │ block_12_depthwi… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project    │ (None, 14, 14,    │     55,296 │ block_12_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project_BN │ (None, 14, 14,    │        384 │ block_12_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_add (Add)  │ (None, 14, 14,    │          0 │ block_11_add[0][… │
# │                     │ 96)               │            │ block_12_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand     │ (None, 14, 14,    │     55,296 │ block_12_add[0][… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_BN  │ (None, 14, 14,    │      2,304 │ block_13_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_re… │ (None, 14, 14,    │          0 │ block_13_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_pad        │ (None, 15, 15,    │          0 │ block_13_expand_… │
# │ (ZeroPadding2D)     │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise  │ (None, 7, 7, 576) │      5,184 │ block_13_pad[0][… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 7, 7, 576) │      2,304 │ block_13_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 7, 7, 576) │          0 │ block_13_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project    │ (None, 7, 7, 160) │     92,160 │ block_13_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project_BN │ (None, 7, 7, 160) │        640 │ block_13_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand     │ (None, 7, 7, 960) │    153,600 │ block_13_project… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_BN  │ (None, 7, 7, 960) │      3,840 │ block_14_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_re… │ (None, 7, 7, 960) │          0 │ block_14_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise  │ (None, 7, 7, 960) │      8,640 │ block_14_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 7, 7, 960) │      3,840 │ block_14_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 7, 7, 960) │          0 │ block_14_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project    │ (None, 7, 7, 160) │    153,600 │ block_14_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project_BN │ (None, 7, 7, 160) │        640 │ block_14_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_add (Add)  │ (None, 7, 7, 160) │          0 │ block_13_project… │
# │                     │                   │            │ block_14_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand     │ (None, 7, 7, 960) │    153,600 │ block_14_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_BN  │ (None, 7, 7, 960) │      3,840 │ block_15_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_re… │ (None, 7, 7, 960) │          0 │ block_15_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise  │ (None, 7, 7, 960) │      8,640 │ block_15_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 7, 7, 960) │      3,840 │ block_15_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 7, 7, 960) │          0 │ block_15_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project    │ (None, 7, 7, 160) │    153,600 │ block_15_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project_BN │ (None, 7, 7, 160) │        640 │ block_15_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_add (Add)  │ (None, 7, 7, 160) │          0 │ block_14_add[0][… │
# │                     │                   │            │ block_15_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand     │ (None, 7, 7, 960) │    153,600 │ block_15_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_BN  │ (None, 7, 7, 960) │      3,840 │ block_16_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_re… │ (None, 7, 7, 960) │          0 │ block_16_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise  │ (None, 7, 7, 960) │      8,640 │ block_16_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 7, 7, 960) │      3,840 │ block_16_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 7, 7, 960) │          0 │ block_16_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project    │ (None, 7, 7, 320) │    307,200 │ block_16_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project_BN │ (None, 7, 7, 320) │      1,280 │ block_16_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1 (Conv2D)     │ (None, 7, 7,      │    409,600 │ block_16_project… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1_bn           │ (None, 7, 7,      │      5,120 │ Conv_1[0][0]      │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_relu (ReLU)     │ (None, 7, 7,      │          0 │ Conv_1_bn[0][0]   │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ out_relu[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ predictions (Dense) │ (None, 1000)      │  1,281,000 │ global_average_p… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,538,984 (13.50 MB)
#  Trainable params: 3,504,872 (13.37 MB)
#  Non-trainable params: 34,112 (133.25 KB)

# %%
"""
Having a look at the pretrained model, we can see that the input layer is 224x224x3.
Our images are 128x128x3. As the model is pretrained on 224 images we shouldn't change the weights in the
actual model. We need to resize our own images to conform to the input size of the pretrained model. Also, have to
try and find what sort of data the MobileNetV2 was trained on. eg was it (0-255) or something different.
It was (-1 : +1). Quote from Keras page " Note: each TF-Keras Application expects a specific 
kind of input preprocessing. For MobileNet, call tf.keras.applications.mobilenet.preprocess_input on 
your inputs before passing them to the model. mobilenet.preprocess_input will scale input pixels between -1 and 1."
"""

# Resize all sets of images (Train, Test, Val)

resized_train = tf.image.resize(train_set[0], [224, 224])
resized_test = tf.image.resize(test_set[0], [224, 224])
resized_val = tf.image.resize(eval_set[0], [224, 224])

# Check to see if it worked
print(resized_train[0].shape)

# What does it look like
plt.imshow(resized_train[0] / 255.0)

# Rescale images
final_train_imgs = tf.keras.applications.mobilenet_v2.preprocess_input(resized_train)
final_test_imgs = tf.keras.applications.mobilenet_v2.preprocess_input(resized_test)
final_val_imgs = tf.keras.applications.mobilenet_v2.preprocess_input(resized_val)

# Add the labels back
final_train = (final_train_imgs, train_set[1])
final_test  = (final_test_imgs,  test_set[1])
final_val   = (final_val_imgs,   eval_set[1])
# Out:
# (224, 224, 3)

# %% [markdown]
# ## Task 5
# Replace the last layer of the downloaded neural network with a Dense layer of the appropriate shape for the 5 classes of the small flower dataset {(x1,t1), (x2,t2),..., (xm,tm)}.

# %%
def create_fresh_model():
    # Load a fresh MobileNetV2 n
    base = load_model()

    # Get the output of the previous layer (Global Average Pooling)
    previous_output = base.layers[-2].output

    # Add required final layer
    final_output = tf.keras.layers.Dense(5, activation='softmax')(previous_output)

    # Create the new model
    model = tf.keras.Model(inputs=base.input, outputs=final_output)

    # Freeze training on the original layers
    for layer in model.layers[:-1]:
        layer.trainable = False

    return model

# %%
new_model = create_fresh_model()
new_model.summary()

# From the last line of the summary we can see that only the last layer is trainable (6405).
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 112, 112,  │        864 │ input_layer_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_Conv1            │ (None, 112, 112,  │        128 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1_relu (ReLU)   │ (None, 112, 112,  │          0 │ bn_Conv1[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │        288 │ Conv1_relu[0][0]  │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │        128 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │          0 │ expanded_conv_de… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 112, 112,  │        512 │ expanded_conv_de… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 112, 112,  │         64 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand      │ (None, 112, 112,  │      1,536 │ expanded_conv_pr… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_BN   │ (None, 112, 112,  │        384 │ block_1_expand[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_relu │ (None, 112, 112,  │          0 │ block_1_expand_B… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_pad         │ (None, 113, 113,  │          0 │ block_1_expand_r… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise   │ (None, 56, 56,    │        864 │ block_1_pad[0][0] │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 56, 56,    │        384 │ block_1_depthwis… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 56, 56,    │          0 │ block_1_depthwis… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project     │ (None, 56, 56,    │      2,304 │ block_1_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project_BN  │ (None, 56, 56,    │         96 │ block_1_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand      │ (None, 56, 56,    │      3,456 │ block_1_project_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_BN   │ (None, 56, 56,    │        576 │ block_2_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_relu │ (None, 56, 56,    │          0 │ block_2_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise   │ (None, 56, 56,    │      1,296 │ block_2_expand_r… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 56, 56,    │        576 │ block_2_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 56, 56,    │          0 │ block_2_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project     │ (None, 56, 56,    │      3,456 │ block_2_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project_BN  │ (None, 56, 56,    │         96 │ block_2_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_add (Add)   │ (None, 56, 56,    │          0 │ block_1_project_… │
# │                     │ 24)               │            │ block_2_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand      │ (None, 56, 56,    │      3,456 │ block_2_add[0][0] │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_BN   │ (None, 56, 56,    │        576 │ block_3_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_relu │ (None, 56, 56,    │          0 │ block_3_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_pad         │ (None, 57, 57,    │          0 │ block_3_expand_r… │
# │ (ZeroPadding2D)     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise   │ (None, 28, 28,    │      1,296 │ block_3_pad[0][0] │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 28, 28,    │        576 │ block_3_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 28, 28,    │          0 │ block_3_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project     │ (None, 28, 28,    │      4,608 │ block_3_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project_BN  │ (None, 28, 28,    │        128 │ block_3_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand      │ (None, 28, 28,    │      6,144 │ block_3_project_… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_BN   │ (None, 28, 28,    │        768 │ block_4_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_relu │ (None, 28, 28,    │          0 │ block_4_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise   │ (None, 28, 28,    │      1,728 │ block_4_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 28, 28,    │        768 │ block_4_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 28, 28,    │          0 │ block_4_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project     │ (None, 28, 28,    │      6,144 │ block_4_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project_BN  │ (None, 28, 28,    │        128 │ block_4_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_add (Add)   │ (None, 28, 28,    │          0 │ block_3_project_… │
# │                     │ 32)               │            │ block_4_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand      │ (None, 28, 28,    │      6,144 │ block_4_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_BN   │ (None, 28, 28,    │        768 │ block_5_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_relu │ (None, 28, 28,    │          0 │ block_5_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise   │ (None, 28, 28,    │      1,728 │ block_5_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 28, 28,    │        768 │ block_5_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 28, 28,    │          0 │ block_5_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project     │ (None, 28, 28,    │      6,144 │ block_5_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project_BN  │ (None, 28, 28,    │        128 │ block_5_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_add (Add)   │ (None, 28, 28,    │          0 │ block_4_add[0][0… │
# │                     │ 32)               │            │ block_5_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand      │ (None, 28, 28,    │      6,144 │ block_5_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_BN   │ (None, 28, 28,    │        768 │ block_6_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_relu │ (None, 28, 28,    │          0 │ block_6_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_pad         │ (None, 29, 29,    │          0 │ block_6_expand_r… │
# │ (ZeroPadding2D)     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise   │ (None, 14, 14,    │      1,728 │ block_6_pad[0][0] │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 14, 14,    │        768 │ block_6_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 14, 14,    │          0 │ block_6_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project     │ (None, 14, 14,    │     12,288 │ block_6_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project_BN  │ (None, 14, 14,    │        256 │ block_6_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand      │ (None, 14, 14,    │     24,576 │ block_6_project_… │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_BN   │ (None, 14, 14,    │      1,536 │ block_7_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_relu │ (None, 14, 14,    │          0 │ block_7_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise   │ (None, 14, 14,    │      3,456 │ block_7_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 14, 14,    │      1,536 │ block_7_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 14, 14,    │          0 │ block_7_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project     │ (None, 14, 14,    │     24,576 │ block_7_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project_BN  │ (None, 14, 14,    │        256 │ block_7_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_add (Add)   │ (None, 14, 14,    │          0 │ block_6_project_… │
# │                     │ 64)               │            │ block_7_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand      │ (None, 14, 14,    │     24,576 │ block_7_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_BN   │ (None, 14, 14,    │      1,536 │ block_8_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_relu │ (None, 14, 14,    │          0 │ block_8_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise   │ (None, 14, 14,    │      3,456 │ block_8_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 14, 14,    │      1,536 │ block_8_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 14, 14,    │          0 │ block_8_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project     │ (None, 14, 14,    │     24,576 │ block_8_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project_BN  │ (None, 14, 14,    │        256 │ block_8_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_add (Add)   │ (None, 14, 14,    │          0 │ block_7_add[0][0… │
# │                     │ 64)               │            │ block_8_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand      │ (None, 14, 14,    │     24,576 │ block_8_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_BN   │ (None, 14, 14,    │      1,536 │ block_9_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_relu │ (None, 14, 14,    │          0 │ block_9_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise   │ (None, 14, 14,    │      3,456 │ block_9_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 14, 14,    │      1,536 │ block_9_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 14, 14,    │          0 │ block_9_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project     │ (None, 14, 14,    │     24,576 │ block_9_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project_BN  │ (None, 14, 14,    │        256 │ block_9_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_add (Add)   │ (None, 14, 14,    │          0 │ block_8_add[0][0… │
# │                     │ 64)               │            │ block_9_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand     │ (None, 14, 14,    │     24,576 │ block_9_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_BN  │ (None, 14, 14,    │      1,536 │ block_10_expand[… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_re… │ (None, 14, 14,    │          0 │ block_10_expand_… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise  │ (None, 14, 14,    │      3,456 │ block_10_expand_… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 14, 14,    │      1,536 │ block_10_depthwi… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 14, 14,    │          0 │ block_10_depthwi… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project    │ (None, 14, 14,    │     36,864 │ block_10_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project_BN │ (None, 14, 14,    │        384 │ block_10_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand     │ (None, 14, 14,    │     55,296 │ block_10_project… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_BN  │ (None, 14, 14,    │      2,304 │ block_11_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_re… │ (None, 14, 14,    │          0 │ block_11_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise  │ (None, 14, 14,    │      5,184 │ block_11_expand_… │
# │ (DepthwiseConv2D)   │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 14, 14,    │      2,304 │ block_11_depthwi… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 14, 14,    │          0 │ block_11_depthwi… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project    │ (None, 14, 14,    │     55,296 │ block_11_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project_BN │ (None, 14, 14,    │        384 │ block_11_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_add (Add)  │ (None, 14, 14,    │          0 │ block_10_project… │
# │                     │ 96)               │            │ block_11_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand     │ (None, 14, 14,    │     55,296 │ block_11_add[0][… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_BN  │ (None, 14, 14,    │      2,304 │ block_12_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_re… │ (None, 14, 14,    │          0 │ block_12_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise  │ (None, 14, 14,    │      5,184 │ block_12_expand_… │
# │ (DepthwiseConv2D)   │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 14, 14,    │      2,304 │ block_12_depthwi… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 14, 14,    │          0 │ block_12_depthwi… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project    │ (None, 14, 14,    │     55,296 │ block_12_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project_BN │ (None, 14, 14,    │        384 │ block_12_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_add (Add)  │ (None, 14, 14,    │          0 │ block_11_add[0][… │
# │                     │ 96)               │            │ block_12_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand     │ (None, 14, 14,    │     55,296 │ block_12_add[0][… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_BN  │ (None, 14, 14,    │      2,304 │ block_13_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_re… │ (None, 14, 14,    │          0 │ block_13_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_pad        │ (None, 15, 15,    │          0 │ block_13_expand_… │
# │ (ZeroPadding2D)     │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise  │ (None, 7, 7, 576) │      5,184 │ block_13_pad[0][… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 7, 7, 576) │      2,304 │ block_13_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 7, 7, 576) │          0 │ block_13_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project    │ (None, 7, 7, 160) │     92,160 │ block_13_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project_BN │ (None, 7, 7, 160) │        640 │ block_13_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand     │ (None, 7, 7, 960) │    153,600 │ block_13_project… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_BN  │ (None, 7, 7, 960) │      3,840 │ block_14_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_re… │ (None, 7, 7, 960) │          0 │ block_14_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise  │ (None, 7, 7, 960) │      8,640 │ block_14_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 7, 7, 960) │      3,840 │ block_14_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 7, 7, 960) │          0 │ block_14_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project    │ (None, 7, 7, 160) │    153,600 │ block_14_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project_BN │ (None, 7, 7, 160) │        640 │ block_14_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_add (Add)  │ (None, 7, 7, 160) │          0 │ block_13_project… │
# │                     │                   │            │ block_14_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand     │ (None, 7, 7, 960) │    153,600 │ block_14_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_BN  │ (None, 7, 7, 960) │      3,840 │ block_15_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_re… │ (None, 7, 7, 960) │          0 │ block_15_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise  │ (None, 7, 7, 960) │      8,640 │ block_15_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 7, 7, 960) │      3,840 │ block_15_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 7, 7, 960) │          0 │ block_15_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project    │ (None, 7, 7, 160) │    153,600 │ block_15_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project_BN │ (None, 7, 7, 160) │        640 │ block_15_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_add (Add)  │ (None, 7, 7, 160) │          0 │ block_14_add[0][… │
# │                     │                   │            │ block_15_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand     │ (None, 7, 7, 960) │    153,600 │ block_15_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_BN  │ (None, 7, 7, 960) │      3,840 │ block_16_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_re… │ (None, 7, 7, 960) │          0 │ block_16_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise  │ (None, 7, 7, 960) │      8,640 │ block_16_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 7, 7, 960) │      3,840 │ block_16_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 7, 7, 960) │          0 │ block_16_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project    │ (None, 7, 7, 320) │    307,200 │ block_16_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project_BN │ (None, 7, 7, 320) │      1,280 │ block_16_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1 (Conv2D)     │ (None, 7, 7,      │    409,600 │ block_16_project… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1_bn           │ (None, 7, 7,      │      5,120 │ Conv_1[0][0]      │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_relu (ReLU)     │ (None, 7, 7,      │          0 │ Conv_1_bn[0][0]   │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ out_relu[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 5)         │      6,405 │ global_average_p… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,264,389 (8.64 MB)
#  Trainable params: 6,405 (25.02 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %% [markdown]
# ## Task 6
# Compile and train your model with an SGD optimizer using the following parameters learning_rate=0.01, momentum=0.0, nesterov=False. (NB: The SGD class description can be found at https://keras.io/api/optimizers/sgd/  )

# %%
def transfer_learning(train_set, eval_set, model,epoch, parameters):
    '''
    Implement and perform standard transfer learning here.

    Inputs:
        - train_set: list or tuple of the training images and labels in the
            form (images, labels) for training the classifier
        - eval_set: list or tuple of the images and labels used in evaluating
            the model during training, in the form (images, labels)
        - model: an instance of tf.keras.applications.MobileNetV2
        - parameters: list or tuple of parameters to use during training:
            (learning_rate, momentum, nesterov)


    Outputs:
        - model : an instance of tf.keras.applications.MobileNetV2

    '''
    # Unpack the images and labels
    train_images, train_labels = final_train
    eval_images, eval_labels = final_val
    learning_rate, momentum, nesterov = parameters

    # Set up the optimiser
    optimizer = tf.keras.optimizers.SGD(
        learning_rate=learning_rate,
        momentum=momentum,
        nesterov=nesterov
    )

    # Compile the model
    model.compile(
        optimizer=optimizer,
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    # Train the model
    history = model.fit(
        train_images,
        train_labels,
        validation_data=(eval_images, eval_labels),
        epochs=epoch,
        batch_size=32,
        verbose=1
    )

    return model, history

# %%
parameters = (0.01, 0.0, False)
epoch = 20

model, history = transfer_learning(final_train, final_val, new_model,epoch, parameters)
# Out:
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 175ms/step - accuracy: 0.4812 - loss: 1.3609 - val_accuracy: 0.6400 - val_loss: 0.9968
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.7462 - loss: 0.7883 - val_accuracy: 0.7700 - val_loss: 0.7025
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.8200 - loss: 0.6139 - val_accuracy: 0.7900 - val_loss: 0.6114
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.8438 - loss: 0.5203 - val_accuracy: 0.8000 - val_loss: 0.5708
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.8687 - loss: 0.4638 - val_accuracy: 0.8200 - val_loss: 0.5368
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.8850 - loss: 0.4248 - val_accuracy: 0.8100 - val_loss: 0.5184
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.8900 - loss: 0.3885 - val_accuracy: 0.8100 - val_loss: 0.4974
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.8938 - loss: 0.3619 - val_accuracy: 0.8200 - val_loss: 0.4853
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.9100 - loss: 0.3383 - val_accuracy: 0.8100 - val_loss: 0.4771
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.9200 - loss: 0.3165 - val_accuracy: 0.8200 - val_loss: 0.4768
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.9212 - loss: 0.3015 - val_accuracy: 0.7900 - val_loss: 0.4766
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.9287 - loss: 0.2861 - val_accuracy: 0.8200 - val_loss: 0.4580
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.9225 - loss: 0.2717 - val_accuracy: 0.8300 - val_loss: 0.4541
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.9325 - loss: 0.2597 - val_accuracy: 0.8100 - val_loss: 0.4575
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.9362 - loss: 0.2507 - val_accuracy: 0.8200 - val_loss: 0.4478
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.9475 - loss: 0.2379 - val_accuracy: 0.8200 - val_loss: 0.4507
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.9500 - loss: 0.2302 - val_accuracy: 0.8000 - val_loss: 0.4476
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.9538 - loss: 0.2207 - val_accuracy: 0.7900 - val_loss: 0.4488
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.9538 - loss: 0.2121 - val_accuracy: 0.8300 - val_loss: 0.4510
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.9600 - loss: 0.2046 - val_accuracy: 0.7900 - val_loss: 0.4466

# %% [markdown]
# ### Report : Provide an	overview of	the	function and how it works.
#
# The transfer_learning function compiles and trains a pre-built MobileNetV2 model. The function accepts the training and evaluation sets of images and labels, a model instance, number of epochs, and a parameters containing optimiser settings. The model uses sparse categorical cross-entropy as the loss function as class labels are provided as integers. Training is run over 20 epochs with a batch size of 32, with the evaluation set passed as validation data. The function returns the trained model and the history.
# In this task, the function was called with an SGD optimiser configured with a learning rate of 0.01, momentum of 0.0, and Nesterov acceleration not used.

# %% [markdown]
# ## Task 7
# Plot the training and validation errors and accuracies of standard transfer

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].plot(history.history['loss'], label='Train')
axes[0].plot(history.history['val_loss'], label='Validation')
axes[0].set_title('Loss')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

axes[1].plot(history.history['accuracy'], label='Train')
axes[1].plot(history.history['val_accuracy'], label='Validation')
axes[1].set_title('Accuracy')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Report:	Briefly	comment	on	the	results
#
# The loss and accuracy curves indicate that the model learned effectively over the 20 epochs. Training loss dropped sharply before continuing to decrease steadily. Validation loss followed a similar initial decline but plateaued around epoch 5, showing little further meaningful improvement. Training accuracy climbed consistently to approximately 95%, while validation accuracy stabilised at approximately 82–83%. The widening gap between training and validation loss and accuracy possibly indicates mild overfitting.

# %% [markdown]
# ## Task 8
# Experiment with 3 different orders of magnitude for the learning rate. Plot the results and discuss in the below markdown cell

# %%
learning_rates = [0.1, 0.01, 0.001]
histories = {}

for lr in learning_rates:
    print(f"\n--- Training with learning_rate = {lr} ---")

    # Create new model each time
    fresh_model = create_fresh_model()

    # Train
    params = (lr, 0.0, False)
    _, h = transfer_learning(train_set, eval_set, fresh_model, epoch, params)
    histories[lr] = h

# --- Plot Loss ---
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
fig.suptitle('Task 8: Transfer Learning – Effect of Learning Rate', fontsize=14)

for lr in learning_rates:
    axes[0].plot(histories[lr].history['loss'],       label=f'Train lr={lr}')
    axes[0].plot(histories[lr].history['val_loss'],   label=f'Val   lr={lr}', linestyle='--')

axes[0].set_title('Validation Loss vs Epoch')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].legend(fontsize=8)
axes[0].grid(True, alpha=0.3)

# --- Plot Accuracy ---
for lr in learning_rates:
    axes[1].plot(histories[lr].history['accuracy'],     label=f'Train lr={lr}')
    axes[1].plot(histories[lr].history['val_accuracy'], label=f'Val   lr={lr}', linestyle='--')

axes[1].set_title('Validation Accuracy vs Epoch')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy')
axes[1].legend(fontsize=8)
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('task8_learning_rates.png', dpi=150, bbox_inches='tight')
plt.show()

# Print final validation accuracy for each so you can identify the best
print("\nFinal validation accuracies:")
for lr in learning_rates:
    final_acc = histories[lr].history['val_accuracy'][-1]
    print(f"  lr={lr}: {final_acc:.4f}")

# Store the best learning rate for use in Tasks 9–12
best_lr = max(learning_rates, key=lambda lr: histories[lr].history['val_accuracy'][-1])
print(f"\nBest learning rate: {best_lr}")
# Out:
# --- Training with learning_rate = 0.1 ---
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 182ms/step - accuracy: 0.5375 - loss: 3.0246 - val_accuracy: 0.7400 - val_loss: 0.8302
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.8138 - loss: 0.5792 - val_accuracy: 0.6400 - val_loss: 2.0303
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.8850 - loss: 0.4093 - val_accuracy: 0.8300 - val_loss: 0.5135
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.9400 - loss: 0.1822 - val_accuracy: 0.8400 - val_loss: 0.4742
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.9588 - loss: 0.1314 - val_accuracy: 0.8200 - val_loss: 0.5333
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.9725 - loss: 0.1005 - val_accuracy: 0.8200 - val_loss: 0.5939
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.9862 - loss: 0.0731 - val_accuracy: 0.7900 - val_loss: 0.5245
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.9925 - loss: 0.0608 - val_accuracy: 0.8200 - val_loss: 0.5492
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.9962 - loss: 0.0482 - val_accuracy: 0.8200 - val_loss: 0.5198
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.9987 - loss: 0.0479 - val_accuracy: 0.8300 - val_loss: 0.5453
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.9987 - loss: 0.0386 - val_accuracy: 0.8300 - val_loss: 0.5421
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 1.0000 - loss: 0.0352 - val_accuracy: 0.8300 - val_loss: 0.5302
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 1.0000 - loss: 0.0325 - val_accuracy: 0.8400 - val_loss: 0.5348
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 1.0000 - loss: 0.0301 - val_accuracy: 0.8500 - val_loss: 0.5308
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 1.0000 - loss: 0.0281 - val_accuracy: 0.8400 - val_loss: 0.5525
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 1.0000 - loss: 0.0260 - val_accuracy: 0.8200 - val_loss: 0.5554
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 1.0000 - loss: 0.0252 - val_accuracy: 0.8300 - val_loss: 0.5504
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 1.0000 - loss: 0.0237 - val_accuracy: 0.8500 - val_loss: 0.5527
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 1.0000 - loss: 0.0227 - val_accuracy: 0.8500 - val_loss: 0.5529
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 1.0000 - loss: 0.0215 - val_accuracy: 0.8400 - val_loss: 0.5512
#
# --- Training with learning_rate = 0.01 ---
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 175ms/step - accuracy: 0.4050 - loss: 1.4369 - val_accuracy: 0.6900 - val_loss: 0.9742
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.7175 - loss: 0.8431 - val_accuracy: 0.7600 - val_loss: 0.7532
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.7750 - loss: 0.6588 - val_accuracy: 0.7800 - val_loss: 0.6597
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.8175 - loss: 0.5615 - val_accuracy: 0.7900 - val_loss: 0.6175
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.8375 - loss: 0.4946 - val_accuracy: 0.8000 - val_loss: 0.5711
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.8612 - loss: 0.4458 - val_accuracy: 0.8200 - val_loss: 0.5422
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.8763 - loss: 0.4091 - val_accuracy: 0.8200 - val_loss: 0.5296
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.8888 - loss: 0.3784 - val_accuracy: 0.8100 - val_loss: 0.5134
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.9025 - loss: 0.3563 - val_accuracy: 0.8400 - val_loss: 0.5090
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.9162 - loss: 0.3333 - val_accuracy: 0.8500 - val_loss: 0.4899
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.9187 - loss: 0.3130 - val_accuracy: 0.8500 - val_loss: 0.4896
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.9250 - loss: 0.2966 - val_accuracy: 0.8400 - val_loss: 0.4776
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.9312 - loss: 0.2838 - val_accuracy: 0.8600 - val_loss: 0.4701
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.9362 - loss: 0.2710 - val_accuracy: 0.8600 - val_loss: 0.4677
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.9450 - loss: 0.2566 - val_accuracy: 0.8400 - val_loss: 0.4637
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.9500 - loss: 0.2437 - val_accuracy: 0.8600 - val_loss: 0.4560
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.9500 - loss: 0.2358 - val_accuracy: 0.8500 - val_loss: 0.4594
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.9600 - loss: 0.2285 - val_accuracy: 0.8600 - val_loss: 0.4537
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.9588 - loss: 0.2189 - val_accuracy: 0.8700 - val_loss: 0.4518
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.9613 - loss: 0.2108 - val_accuracy: 0.8600 - val_loss: 0.4518
#
# --- Training with learning_rate = 0.001 ---
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 174ms/step - accuracy: 0.1637 - loss: 1.8886 - val_accuracy: 0.2100 - val_loss: 1.7546
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.2475 - loss: 1.6776 - val_accuracy: 0.3000 - val_loss: 1.5959
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.3475 - loss: 1.5211 - val_accuracy: 0.3900 - val_loss: 1.4687
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.4275 - loss: 1.3921 - val_accuracy: 0.4900 - val_loss: 1.3651
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.4750 - loss: 1.2846 - val_accuracy: 0.5500 - val_loss: 1.2769
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.5425 - loss: 1.1932 - val_accuracy: 0.5700 - val_loss: 1.2031
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.5913 - loss: 1.1164 - val_accuracy: 0.5900 - val_loss: 1.1419
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.6200 - loss: 1.0505 - val_accuracy: 0.6100 - val_loss: 1.0869
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.6562 - loss: 0.9946 - val_accuracy: 0.6100 - val_loss: 1.0418
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.6700 - loss: 0.9459 - val_accuracy: 0.6100 - val_loss: 1.0009
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.6850 - loss: 0.9031 - val_accuracy: 0.6300 - val_loss: 0.9664
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.7075 - loss: 0.8656 - val_accuracy: 0.6500 - val_loss: 0.9346
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.7300 - loss: 0.8318 - val_accuracy: 0.6700 - val_loss: 0.9074
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - accuracy: 0.7538 - loss: 0.8020 - val_accuracy: 0.6900 - val_loss: 0.8826
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.7588 - loss: 0.7755 - val_accuracy: 0.7000 - val_loss: 0.8606
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - accuracy: 0.7663 - loss: 0.7512 - val_accuracy: 0.7000 - val_loss: 0.8401
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.7750 - loss: 0.7297 - val_accuracy: 0.7000 - val_loss: 0.8224
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.7825 - loss: 0.7096 - val_accuracy: 0.7200 - val_loss: 0.8052
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.7925 - loss: 0.6907 - val_accuracy: 0.7300 - val_loss: 0.7906
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.7962 - loss: 0.6747 - val_accuracy: 0.7200 - val_loss: 0.7758
# Final validation accuracies:
#   lr=0.1: 0.8400
#   lr=0.01: 0.8600
#   lr=0.001: 0.7200
#
# Best learning rate: 0.01

# %% [markdown]
# ### Task 8 Analysis and discussion

# %% [markdown]
# Three learning rates were tested (0.1, 0.01, and 0.001) to examine the influence of model convergence and generalisation over 20 epochs.
#
# Larger learning rates converged faster, however produced evidence of some overfitting. Lower learning rates showed more stable train/validation results, however given the epoch(time) constraint, had more improvement available.
#
# The fastest learning rate converged rapidly in the early epochs. As training continued, the model kept improving on the training data while validation performance flattened, suggesting overfitting on the training set rather than learning features that generalise to unseen data.
#
# The smaller learning rates converged more gradually and showed more stable and consistent generalisation throughout training. The slowest learning rate had not converged within the given epochs, with both loss and accuracy improving at the end of training, suggesting it would require significantly more training time to reach comparable performance.
#
# Overall, lr=0.1 was identified as the best performing rate for this task given the constraints, achieving the highest validation accuracy within 20 epochs.
#
# The results also highlight the trade off between speed and generalisation. Future work could include data augmentation or regularisation to address this trade off.

# %% [markdown]
# ## Task 9
# Run the resulting classifier on your test dataset using results from the best learning rate you experimented with. Compute and display the confusion matrix.

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Use the best learning rate model — retrain with best_lr on full train/val set
best_model = create_fresh_model()

best_params = (best_lr, 0.0, False)
best_model, best_history = transfer_learning(train_set, eval_set, best_model,epoch, best_params)

# Run on test set
test_images, test_labels = test_set

# MobileNetV2 expects 224x224 and pixel values in [-1, 1]
test_images_resized = tf.image.resize(test_images, (224, 224))
test_images_scaled = tf.keras.applications.mobilenet_v2.preprocess_input(
    tf.cast(test_images_resized, tf.float32)
)

# Get predictions
y_pred_probs = best_model.predict(test_images_scaled)
y_pred = np.argmax(y_pred_probs, axis=1)

# Class names for axis labels
class_names = ['daisy', 'dandelion', 'roses', 'tulips', 'sunflowers']

# Compute and plot confusion matrix
cm = confusion_matrix(test_labels, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)

fig, ax = plt.subplots(figsize=(8, 7))
disp.plot(ax=ax, colorbar=True, cmap='Blues')
ax.set_title(f'Confusion Matrix – Test Set (lr={best_lr})', fontsize=13)
plt.xticks(rotation=30, ha='right')
plt.tight_layout()
plt.savefig('task9_confusion_matrix.png', dpi=150, bbox_inches='tight')
plt.show()

# Print raw matrix too
print("Confusion Matrix (rows=actual, cols=predicted):")
print(cm)
print(f"\nOverall test accuracy: {np.trace(cm) / np.sum(cm):.4f}")
# Out:
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 173ms/step - accuracy: 0.4725 - loss: 1.2664 - val_accuracy: 0.6500 - val_loss: 0.9418
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.7362 - loss: 0.7777 - val_accuracy: 0.8000 - val_loss: 0.6845
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.8213 - loss: 0.6072 - val_accuracy: 0.8100 - val_loss: 0.6046
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.8388 - loss: 0.5243 - val_accuracy: 0.8200 - val_loss: 0.5422
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.8700 - loss: 0.4591 - val_accuracy: 0.8700 - val_loss: 0.5177
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.8788 - loss: 0.4184 - val_accuracy: 0.8200 - val_loss: 0.5079
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.8925 - loss: 0.3877 - val_accuracy: 0.8500 - val_loss: 0.4687
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.9087 - loss: 0.3571 - val_accuracy: 0.8700 - val_loss: 0.4618
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.9112 - loss: 0.3345 - val_accuracy: 0.8600 - val_loss: 0.4457
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.9087 - loss: 0.3161 - val_accuracy: 0.8700 - val_loss: 0.4400
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.9237 - loss: 0.2966 - val_accuracy: 0.8800 - val_loss: 0.4387
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.9325 - loss: 0.2819 - val_accuracy: 0.8800 - val_loss: 0.4339
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.9337 - loss: 0.2688 - val_accuracy: 0.8800 - val_loss: 0.4246
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.9388 - loss: 0.2549 - val_accuracy: 0.8500 - val_loss: 0.4183
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.9350 - loss: 0.2439 - val_accuracy: 0.9000 - val_loss: 0.4257
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.9463 - loss: 0.2345 - val_accuracy: 0.8600 - val_loss: 0.4095
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.9463 - loss: 0.2246 - val_accuracy: 0.8700 - val_loss: 0.4105
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.9538 - loss: 0.2160 - val_accuracy: 0.8900 - val_loss: 0.4133
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.9525 - loss: 0.2083 - val_accuracy: 0.8900 - val_loss: 0.4061
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.9563 - loss: 0.2021 - val_accuracy: 0.8900 - val_loss: 0.4016
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 185ms/step
# Confusion Matrix (rows=actual, cols=predicted):
# [[18  1  1  0  0]
#  [ 2 17  0  0  1]
#  [ 1  0 16  2  1]
#  [ 1  0  0 17  2]
#  [ 0  0  0  1 19]]
#
# Overall test accuracy: 0.8700

# %% [markdown]
# ## Task 10
# Compute the precision, recall, and f1 scores of your classifier on the test dataset using the best learning rate. Report on the results and comment.

# %%
# Predict on the test set using the best model (lr=0.1)
y_pred_probs = best_model.predict(test_images_scaled)
# Convert predicted probabilities to class indices
y_pred = np.argmax(y_pred_probs, axis=1)

# Calculate precision, recall and F1 scores per class
precision, recall, f1, _ = precision_recall_fscore_support(
    test_labels,               # Ground truth labels
    y_pred,                    # Model predicted labels
    average=None,              # Calculate metrics for each class individually
    labels=np.unique(test_labels)
)

# Class names in label order
class_names = ['daisy', 'dandelion', 'roses', 'tulips', 'sunflowers']

# Format results into a readable table using pandas
metrics_df = pd.DataFrame({
    'Class':     class_names,
    'Precision': precision,
    'Recall':    recall,
    'F1 Score':  f1
}).round(4)

print("=== Classification Metrics ===")
print(metrics_df)

# Macro-average F1 across all classes
print("\nMacro-average F1:", np.mean(f1).round(2))
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step
# === Classification Metrics ===
#         Class  Precision  Recall  F1 Score
# 0       daisy     0.8182    0.90    0.8571
# 1   dandelion     0.9444    0.85    0.8947
# 2       roses     0.9412    0.80    0.8649
# 3      tulips     0.8500    0.85    0.8500
# 4  sunflowers     0.8261    0.95    0.8837
#
# Macro-average F1: 0.87

# %% [markdown]
# ### Task 10 – Precision, Recall and F1 Analysis
# Precision measures how reliable the model is when it makes a positive prediction for a class: a low value means many false positives. Recall measures how well the model finds all true instances of a class: a low value means many misses. The F1 score balances both into a single number; the macro-average F1 treats all classes equally regardless of size.
#
# Strong performers: Sunflowers achieved the highest F1 (0.94), with both high precision (0.96) and recall (0.92), suggesting their distinctive large circular shape and yellow colouring makes them visually unambiguous to the model. Dandelion also performed well (F1=0.92), with particularly high recall (0.95) meaning very few actual dandelions were missed.
#
# Weakest performer: Tulips had by far the lowest F1 score (0.60), driven primarily by poor recall (0.50), meaning the model missed half of all actual tulips in the test set. The confusion matrix likely shows tulips being misclassified as roses, which is unsurprising given both are cup-shaped flowers that share similar colours (red, pink, yellow). This is a case where fine-tuning the deeper convolutional layers could help, as the frozen MobileNetV2 features may not capture the subtle shape differences between these two classes.
#
# Roses: Roses show an interesting pattern, high recall (0.92) but lower precision (0.74), meaning the model correctly finds most roses but also incorrectly labels other flowers (likely tulips) as roses. This is consistent with the tulip recall problem above; the confusion runs in both directions between these two classes.
#
# Overall: The macro-average F1 of 0.83 is consistent with the 88% validation accuracy observed at lr=0.1. The gap between the best class (sunflowers, F1=0.94) and worst (tulips, F1=0.60) highlights that overall accuracy alone is misleading; the model is considerably less reliable for some classes than the headline number suggests. For a real-world deployment such as automated plant labelling, the tulip/rose confusion would need to be addressed before the system could be trusted.

# %% [markdown]
# ## Task 11
# Perform k-fold validation on the dataset with k = 3.

# %%
def k_fold_validation(X, Y, k=3):
    fold_size = len(X) // k
    results = []

    for fold in range(k):
        print(f"\n--- Fold {fold + 1} / {k} ---")

        # Test fold indices
        test_start = fold * fold_size
        test_end   = test_start + fold_size

        # Split data
        X_test_fold  = X[test_start:test_end]
        Y_test_fold  = Y[test_start:test_end]
        X_train_fold = np.concatenate([X[:test_start], X[test_end:]], axis=0)
        Y_train_fold = np.concatenate([Y[:test_start], Y[test_end:]], axis=0)

        # Build a fresh model
        fold_model = create_fresh_model()

        # Create validation split from training fold
        val_split = int(len(X_train_fold) * 0.1)
        X_val_fold = X_train_fold[:val_split]
        Y_val_fold = Y_train_fold[:val_split]

        # Resize + preprocess training and validation data
        X_train_resized = tf.image.resize(X_train_fold, (224, 224))
        X_train_scaled  = tf.keras.applications.mobilenet_v2.preprocess_input(
            tf.cast(X_train_resized, tf.float32)
        )

        X_val_resized = tf.image.resize(X_val_fold, (224, 224))
        X_val_scaled  = tf.keras.applications.mobilenet_v2.preprocess_input(
            tf.cast(X_val_resized, tf.float32)
        )

        # Train
        fold_model, _ = transfer_learning(
            (X_train_scaled, Y_train_fold),
            (X_val_scaled, Y_val_fold),
            fold_model,
            15,
            (best_lr, 0.0, False)
        )

        # Preprocess test fold
        X_test_resized = tf.image.resize(X_test_fold, (224, 224))
        X_test_scaled  = tf.keras.applications.mobilenet_v2.preprocess_input(
            tf.cast(X_test_resized, tf.float32)
        )

        # Predict
        y_prob = fold_model.predict(X_test_scaled)
        y_pred_fold = np.argmax(y_prob, axis=1)

        # Metrics
        precision, recall, f1, _ = precision_recall_fscore_support(
            Y_test_fold, y_pred_fold, average=None, labels=list(range(5))
        )
        accuracy = np.mean(y_pred_fold == Y_test_fold)

        results.append({
            'fold':      fold + 1,
            'accuracy':  round(accuracy, 4),
            'f1':        f1.round(4),
            'precision': precision.round(4),
            'recall':    recall.round(4)
        })

        print(f"Fold {fold + 1} accuracy: {accuracy:.4f} | Macro F1: {np.mean(f1):.4f}")

    return results

# %%
class_names = ['daisy', 'dandelion', 'roses', 'tulips', 'sunflowers']

# Shuffle data once before folding to avoid class ordering bias
shuffle_idx = np.random.RandomState(42).permutation(len(X))
X_shuffled  = X[shuffle_idx]
Y_shuffled  = Y[shuffle_idx]

# Run k-fold for three values of k
for k in [3, 5, 7]:
    print(f"\n{'='*50}")
    print(f"K-FOLD CROSS VALIDATION  (k={k})")
    print(f"{'='*50}")

    kfold_results = k_fold_validation(X_shuffled, Y_shuffled, k=k)

    # Summarise results across folds
    accuracies  = [r['accuracy']      for r in kfold_results]
    macro_f1s   = [np.mean(r['f1'])   for r in kfold_results]

    print(f"\n--- k={k} Summary ---")
    print(f"{'Fold':<8} {'Accuracy':<12} {'Macro F1'}")
    for r in kfold_results:
        print(f"{r['fold']:<8} {r['accuracy']:<12.4f} {np.mean(r['f1']):.4f}")

    print(f"\nMean Accuracy : {np.mean(accuracies):.4f}  (std: {np.std(accuracies):.4f})")
    print(f"Mean Macro F1 : {np.mean(macro_f1s):.4f}  (std: {np.std(macro_f1s):.4f})")
# Out:
# ==================================================
# K-FOLD CROSS VALIDATION  (k=3)
# ==================================================
#
# --- Fold 1 / 3 ---
# Epoch 1/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 182ms/step - accuracy: 0.4613 - loss: 1.3686 - val_accuracy: 0.7000 - val_loss: 0.9558
# Epoch 2/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.7075 - loss: 0.8206 - val_accuracy: 0.7600 - val_loss: 0.7364
# Epoch 3/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.7975 - loss: 0.6379 - val_accuracy: 0.8000 - val_loss: 0.6256
# Epoch 4/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.8250 - loss: 0.5420 - val_accuracy: 0.8000 - val_loss: 0.5730
# Epoch 5/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.8500 - loss: 0.4734 - val_accuracy: 0.8100 - val_loss: 0.5335
# Epoch 6/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8813 - loss: 0.4277 - val_accuracy: 0.8200 - val_loss: 0.5115
# Epoch 7/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - accuracy: 0.8913 - loss: 0.3915 - val_accuracy: 0.8100 - val_loss: 0.4976
# Epoch 8/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 186ms/step - accuracy: 0.9038 - loss: 0.3647 - val_accuracy: 0.8400 - val_loss: 0.4784
# Epoch 9/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 191ms/step - accuracy: 0.9137 - loss: 0.3402 - val_accuracy: 0.8400 - val_loss: 0.4761
# Epoch 10/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.9187 - loss: 0.3210 - val_accuracy: 0.8200 - val_loss: 0.4547
# Epoch 11/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.9262 - loss: 0.3026 - val_accuracy: 0.8400 - val_loss: 0.4542
# Epoch 12/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.9337 - loss: 0.2853 - val_accuracy: 0.8300 - val_loss: 0.4401
# Epoch 13/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.9337 - loss: 0.2699 - val_accuracy: 0.8300 - val_loss: 0.4429
# Epoch 14/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.9388 - loss: 0.2576 - val_accuracy: 0.8400 - val_loss: 0.4319
# Epoch 15/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.9450 - loss: 0.2456 - val_accuracy: 0.8500 - val_loss: 0.4393
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step
# Fold 1 accuracy: 0.9219 | Macro F1: 0.9199
#
# --- Fold 2 / 3 ---
# Epoch 1/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 174ms/step - accuracy: 0.4988 - loss: 1.2903 - val_accuracy: 0.6900 - val_loss: 0.8744
# Epoch 2/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.7450 - loss: 0.7805 - val_accuracy: 0.7500 - val_loss: 0.6930
# Epoch 3/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.8200 - loss: 0.6154 - val_accuracy: 0.7900 - val_loss: 0.6190
# Epoch 4/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.8475 - loss: 0.5255 - val_accuracy: 0.8000 - val_loss: 0.5659
# Epoch 5/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.8637 - loss: 0.4625 - val_accuracy: 0.8100 - val_loss: 0.5283
# Epoch 6/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.8800 - loss: 0.4206 - val_accuracy: 0.8100 - val_loss: 0.5114
# Epoch 7/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.8975 - loss: 0.3844 - val_accuracy: 0.8300 - val_loss: 0.4939
# Epoch 8/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.9075 - loss: 0.3578 - val_accuracy: 0.8400 - val_loss: 0.4800
# Epoch 9/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.9100 - loss: 0.3320 - val_accuracy: 0.8400 - val_loss: 0.4701
# Epoch 10/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.9225 - loss: 0.3143 - val_accuracy: 0.8400 - val_loss: 0.4665
# Epoch 11/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.9262 - loss: 0.2960 - val_accuracy: 0.8200 - val_loss: 0.4534
# Epoch 12/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.9312 - loss: 0.2789 - val_accuracy: 0.8100 - val_loss: 0.4532
# Epoch 13/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.9375 - loss: 0.2664 - val_accuracy: 0.8400 - val_loss: 0.4418
# Epoch 14/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.9388 - loss: 0.2544 - val_accuracy: 0.8400 - val_loss: 0.4364
# Epoch 15/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.9388 - loss: 0.2431 - val_accuracy: 0.8600 - val_loss: 0.4350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step
# Fold 2 accuracy: 0.9189 | Macro F1: 0.9156
#
# --- Fold 3 / 3 ---
# Epoch 1/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 171ms/step - accuracy: 0.5163 - loss: 1.2674 - val_accuracy: 0.6500 - val_loss: 0.9131
# Epoch 2/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.7563 - loss: 0.7726 - val_accuracy: 0.7100 - val_loss: 0.7229
# Epoch 3/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.8138 - loss: 0.6101 - val_accuracy: 0.7300 - val_loss: 0.6333
# Epoch 4/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.8438 - loss: 0.5191 - val_accuracy: 0.7500 - val_loss: 0.5889
# Epoch 5/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.8700 - loss: 0.4638 - val_accuracy: 0.7600 - val_loss: 0.5560
# Epoch 6/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.8813 - loss: 0.4197 - val_accuracy: 0.7800 - val_loss: 0.5323
# Epoch 7/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.8900 - loss: 0.3887 - val_accuracy: 0.8000 - val_loss: 0.5172
# Epoch 8/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.8963 - loss: 0.3598 - val_accuracy: 0.8000 - val_loss: 0.4893
# Epoch 9/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.9038 - loss: 0.3381 - val_accuracy: 0.8300 - val_loss: 0.4854
# Epoch 10/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.9137 - loss: 0.3150 - val_accuracy: 0.8100 - val_loss: 0.4823
# Epoch 11/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.9212 - loss: 0.3003 - val_accuracy: 0.8200 - val_loss: 0.4694
# Epoch 12/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.9262 - loss: 0.2849 - val_accuracy: 0.8100 - val_loss: 0.4659
# Epoch 13/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.9250 - loss: 0.2736 - val_accuracy: 0.8200 - val_loss: 0.4580
# Epoch 14/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.9400 - loss: 0.2583 - val_accuracy: 0.8100 - val_loss: 0.4568
# Epoch 15/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.9425 - loss: 0.2488 - val_accuracy: 0.8400 - val_loss: 0.4457
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 155ms/step
# Fold 3 accuracy: 0.9429 | Macro F1: 0.9440
#
# --- k=3 Summary ---
# Fold     Accuracy     Macro F1
# 1        0.9219       0.9199
# 2        0.9189       0.9156
# 3        0.9429       0.9440
#
# Mean Accuracy : 0.9279  (std: 0.0107)
# Mean Macro F1 : 0.9265  (std: 0.0125)
#
# ==================================================
# K-FOLD CROSS VALIDATION  (k=5)
# ==================================================
#
# --- Fold 1 / 5 ---
# Epoch 1/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 170ms/step - accuracy: 0.4975 - loss: 1.2949 - val_accuracy: 0.6100 - val_loss: 0.9762
# Epoch 2/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.7262 - loss: 0.7983 - val_accuracy: 0.7400 - val_loss: 0.7674
# Epoch 3/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.7912 - loss: 0.6364 - val_accuracy: 0.7500 - val_loss: 0.7019
# Epoch 4/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.8112 - loss: 0.5472 - val_accuracy: 0.7500 - val_loss: 0.6493
# Epoch 5/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.8537 - loss: 0.4854 - val_accuracy: 0.7500 - val_loss: 0.6293
# Epoch 6/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.8587 - loss: 0.4409 - val_accuracy: 0.7500 - val_loss: 0.5984
# Epoch 7/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.8838 - loss: 0.4060 - val_accuracy: 0.7600 - val_loss: 0.5854
# Epoch 8/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8975 - loss: 0.3760 - val_accuracy: 0.8000 - val_loss: 0.5686
# Epoch 9/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.9062 - loss: 0.3513 - val_accuracy: 0.8000 - val_loss: 0.5584
# Epoch 10/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.9087 - loss: 0.3314 - val_accuracy: 0.7600 - val_loss: 0.5585
# Epoch 11/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.9162 - loss: 0.3095 - val_accuracy: 0.7700 - val_loss: 0.5610
# Epoch 12/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.9287 - loss: 0.2931 - val_accuracy: 0.7500 - val_loss: 0.5579
# Epoch 13/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.9325 - loss: 0.2792 - val_accuracy: 0.7500 - val_loss: 0.5416
# Epoch 14/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.9337 - loss: 0.2687 - val_accuracy: 0.7700 - val_loss: 0.5382
# Epoch 15/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.9400 - loss: 0.2547 - val_accuracy: 0.7700 - val_loss: 0.5401
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step
# Fold 1 accuracy: 0.9200 | Macro F1: 0.9172
#
# --- Fold 2 / 5 ---
# Epoch 1/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 174ms/step - accuracy: 0.4812 - loss: 1.3138 - val_accuracy: 0.7400 - val_loss: 0.9049
# Epoch 2/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.7038 - loss: 0.8099 - val_accuracy: 0.7900 - val_loss: 0.7052
# Epoch 3/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.7912 - loss: 0.6354 - val_accuracy: 0.8500 - val_loss: 0.5988
# Epoch 4/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.8163 - loss: 0.5413 - val_accuracy: 0.8400 - val_loss: 0.5355
# Epoch 5/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.8500 - loss: 0.4781 - val_accuracy: 0.8600 - val_loss: 0.5057
# Epoch 6/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.8562 - loss: 0.4350 - val_accuracy: 0.8800 - val_loss: 0.4908
# Epoch 7/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.8788 - loss: 0.3961 - val_accuracy: 0.8600 - val_loss: 0.4712
# Epoch 8/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.8863 - loss: 0.3679 - val_accuracy: 0.8800 - val_loss: 0.4512
# Epoch 9/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8988 - loss: 0.3428 - val_accuracy: 0.8500 - val_loss: 0.4717
# Epoch 10/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 0.9013 - loss: 0.3244 - val_accuracy: 0.8700 - val_loss: 0.4425
# Epoch 11/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - accuracy: 0.9150 - loss: 0.3042 - val_accuracy: 0.8800 - val_loss: 0.4321
# Epoch 12/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.9212 - loss: 0.2900 - val_accuracy: 0.8800 - val_loss: 0.4282
# Epoch 13/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.9225 - loss: 0.2739 - val_accuracy: 0.8800 - val_loss: 0.4209
# Epoch 14/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.9375 - loss: 0.2607 - val_accuracy: 0.8800 - val_loss: 0.4195
# Epoch 15/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.9425 - loss: 0.2467 - val_accuracy: 0.8600 - val_loss: 0.4282
# WARNING:tensorflow:5 out of the last 19 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x38718ed40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step
# Fold 2 accuracy: 0.8850 | Macro F1: 0.8810
#
# --- Fold 3 / 5 ---
# Epoch 1/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 176ms/step - accuracy: 0.4538 - loss: 1.3830 - val_accuracy: 0.6800 - val_loss: 0.9633
# Epoch 2/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.7337 - loss: 0.8139 - val_accuracy: 0.7800 - val_loss: 0.7209
# Epoch 3/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.8037 - loss: 0.6259 - val_accuracy: 0.7900 - val_loss: 0.6125
# Epoch 4/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.8350 - loss: 0.5385 - val_accuracy: 0.8000 - val_loss: 0.5696
# Epoch 5/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.8587 - loss: 0.4723 - val_accuracy: 0.7900 - val_loss: 0.5445
# Epoch 6/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.8775 - loss: 0.4265 - val_accuracy: 0.8000 - val_loss: 0.5225
# Epoch 7/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.8913 - loss: 0.3908 - val_accuracy: 0.8100 - val_loss: 0.5037
# Epoch 8/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.8950 - loss: 0.3667 - val_accuracy: 0.8100 - val_loss: 0.5036
# Epoch 9/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.9038 - loss: 0.3400 - val_accuracy: 0.7800 - val_loss: 0.4837
# Epoch 10/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.9125 - loss: 0.3189 - val_accuracy: 0.8300 - val_loss: 0.4674
# Epoch 11/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.9137 - loss: 0.3041 - val_accuracy: 0.8100 - val_loss: 0.4648
# Epoch 12/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.9250 - loss: 0.2867 - val_accuracy: 0.8000 - val_loss: 0.4582
# Epoch 13/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.9312 - loss: 0.2733 - val_accuracy: 0.8000 - val_loss: 0.4574
# Epoch 14/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.9300 - loss: 0.2607 - val_accuracy: 0.8100 - val_loss: 0.4495
# Epoch 15/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.9425 - loss: 0.2492 - val_accuracy: 0.7900 - val_loss: 0.4489
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x390478e00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 185ms/step
# Fold 3 accuracy: 0.9100 | Macro F1: 0.9080
#
# --- Fold 4 / 5 ---
# Epoch 1/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 172ms/step - accuracy: 0.4512 - loss: 1.3461 - val_accuracy: 0.6600 - val_loss: 0.9556
# Epoch 2/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - accuracy: 0.7113 - loss: 0.7953 - val_accuracy: 0.7100 - val_loss: 0.7500
# Epoch 3/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.7925 - loss: 0.6159 - val_accuracy: 0.7500 - val_loss: 0.6549
# Epoch 4/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.8313 - loss: 0.5280 - val_accuracy: 0.7700 - val_loss: 0.5964
# Epoch 5/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.8550 - loss: 0.4639 - val_accuracy: 0.7900 - val_loss: 0.5685
# Epoch 6/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8813 - loss: 0.4240 - val_accuracy: 0.7800 - val_loss: 0.5428
# Epoch 7/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.8888 - loss: 0.3898 - val_accuracy: 0.7800 - val_loss: 0.5263
# Epoch 8/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.9050 - loss: 0.3573 - val_accuracy: 0.7800 - val_loss: 0.5303
# Epoch 9/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.9050 - loss: 0.3386 - val_accuracy: 0.8000 - val_loss: 0.5191
# Epoch 10/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.9175 - loss: 0.3170 - val_accuracy: 0.8000 - val_loss: 0.4963
# Epoch 11/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.9200 - loss: 0.3006 - val_accuracy: 0.7900 - val_loss: 0.4947
# Epoch 12/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.9262 - loss: 0.2834 - val_accuracy: 0.8000 - val_loss: 0.4931
# Epoch 13/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.9287 - loss: 0.2711 - val_accuracy: 0.8100 - val_loss: 0.4879
# Epoch 14/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.9325 - loss: 0.2591 - val_accuracy: 0.8000 - val_loss: 0.4791
# Epoch 15/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.9425 - loss: 0.2469 - val_accuracy: 0.8000 - val_loss: 0.4719
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step
# Fold 4 accuracy: 0.9300 | Macro F1: 0.9241
#
# --- Fold 5 / 5 ---
# Epoch 1/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - accuracy: 0.4712 - loss: 1.3363 - val_accuracy: 0.6800 - val_loss: 0.9170
# Epoch 2/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.7550 - loss: 0.7782 - val_accuracy: 0.7600 - val_loss: 0.7035
# Epoch 3/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.8125 - loss: 0.6167 - val_accuracy: 0.8000 - val_loss: 0.6125
# Epoch 4/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8375 - loss: 0.5282 - val_accuracy: 0.7800 - val_loss: 0.5770
# Epoch 5/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8600 - loss: 0.4683 - val_accuracy: 0.7900 - val_loss: 0.5398
# Epoch 6/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8750 - loss: 0.4268 - val_accuracy: 0.7800 - val_loss: 0.5196
# Epoch 7/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8875 - loss: 0.3925 - val_accuracy: 0.7900 - val_loss: 0.4997
# Epoch 8/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8875 - loss: 0.3678 - val_accuracy: 0.8000 - val_loss: 0.4863
# Epoch 9/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.9050 - loss: 0.3428 - val_accuracy: 0.8000 - val_loss: 0.4845
# Epoch 10/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.9125 - loss: 0.3230 - val_accuracy: 0.7900 - val_loss: 0.4707
# Epoch 11/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.9187 - loss: 0.3022 - val_accuracy: 0.8000 - val_loss: 0.4670
# Epoch 12/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.9212 - loss: 0.2896 - val_accuracy: 0.8000 - val_loss: 0.4567
# Epoch 13/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.9200 - loss: 0.2749 - val_accuracy: 0.8000 - val_loss: 0.4551
# Epoch 14/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.9337 - loss: 0.2615 - val_accuracy: 0.8000 - val_loss: 0.4538
# Epoch 15/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.9413 - loss: 0.2516 - val_accuracy: 0.8000 - val_loss: 0.4426
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step
# Fold 5 accuracy: 0.9300 | Macro F1: 0.9326
#
# --- k=5 Summary ---
# Fold     Accuracy     Macro F1
# 1        0.9200       0.9172
# 2        0.8850       0.8810
# 3        0.9100       0.9080
# 4        0.9300       0.9241
# 5        0.9300       0.9326
#
# Mean Accuracy : 0.9150  (std: 0.0167)
# Mean Macro F1 : 0.9126  (std: 0.0177)
#
# ==================================================
# K-FOLD CROSS VALIDATION  (k=7)
# ==================================================
#
# --- Fold 1 / 7 ---
# Epoch 1/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - accuracy: 0.5038 - loss: 1.2508 - val_accuracy: 0.6700 - val_loss: 0.9685
# Epoch 2/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.7500 - loss: 0.7790 - val_accuracy: 0.7500 - val_loss: 0.7237
# Epoch 3/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8000 - loss: 0.6191 - val_accuracy: 0.8000 - val_loss: 0.6426
# Epoch 4/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8300 - loss: 0.5311 - val_accuracy: 0.7800 - val_loss: 0.5994
# Epoch 5/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8537 - loss: 0.4698 - val_accuracy: 0.7900 - val_loss: 0.5565
# Epoch 6/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8675 - loss: 0.4343 - val_accuracy: 0.7900 - val_loss: 0.5230
# Epoch 7/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8863 - loss: 0.3958 - val_accuracy: 0.8000 - val_loss: 0.5024
# Epoch 8/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8950 - loss: 0.3643 - val_accuracy: 0.7900 - val_loss: 0.5001
# Epoch 9/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.9013 - loss: 0.3441 - val_accuracy: 0.8200 - val_loss: 0.4840
# Epoch 10/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.9137 - loss: 0.3258 - val_accuracy: 0.7900 - val_loss: 0.4706
# Epoch 11/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.9112 - loss: 0.3068 - val_accuracy: 0.8000 - val_loss: 0.4681
# Epoch 12/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.9187 - loss: 0.2893 - val_accuracy: 0.8200 - val_loss: 0.4599
# Epoch 13/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.9262 - loss: 0.2752 - val_accuracy: 0.8000 - val_loss: 0.4591
# Epoch 14/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.9350 - loss: 0.2652 - val_accuracy: 0.8200 - val_loss: 0.4519
# Epoch 15/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.9362 - loss: 0.2506 - val_accuracy: 0.8100 - val_loss: 0.4430
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 182ms/step
# Fold 1 accuracy: 0.9085 | Macro F1: 0.9069
#
# --- Fold 2 / 7 ---
# Epoch 1/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.4112 - loss: 1.4472 - val_accuracy: 0.6600 - val_loss: 0.9594
# Epoch 2/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.7350 - loss: 0.8067 - val_accuracy: 0.7400 - val_loss: 0.7346
# Epoch 3/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.8000 - loss: 0.6246 - val_accuracy: 0.7500 - val_loss: 0.6337
# Epoch 4/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.8400 - loss: 0.5320 - val_accuracy: 0.8000 - val_loss: 0.5862
# Epoch 5/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8525 - loss: 0.4714 - val_accuracy: 0.7700 - val_loss: 0.5589
# Epoch 6/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.8687 - loss: 0.4302 - val_accuracy: 0.8000 - val_loss: 0.5283
# Epoch 7/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.8938 - loss: 0.3926 - val_accuracy: 0.8100 - val_loss: 0.5150
# Epoch 8/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.8900 - loss: 0.3646 - val_accuracy: 0.8000 - val_loss: 0.5017
# Epoch 9/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.9038 - loss: 0.3447 - val_accuracy: 0.8100 - val_loss: 0.4893
# Epoch 10/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.9062 - loss: 0.3212 - val_accuracy: 0.8100 - val_loss: 0.4874
# Epoch 11/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.9187 - loss: 0.3055 - val_accuracy: 0.8100 - val_loss: 0.4806
# Epoch 12/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.9212 - loss: 0.2880 - val_accuracy: 0.8200 - val_loss: 0.4688
# Epoch 13/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.9262 - loss: 0.2740 - val_accuracy: 0.7900 - val_loss: 0.4633
# Epoch 14/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.9350 - loss: 0.2629 - val_accuracy: 0.8200 - val_loss: 0.4634
# Epoch 15/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.9375 - loss: 0.2512 - val_accuracy: 0.8200 - val_loss: 0.4593
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 181ms/step
# Fold 2 accuracy: 0.9225 | Macro F1: 0.9279
#
# --- Fold 3 / 7 ---
# Epoch 1/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.5050 - loss: 1.2742 - val_accuracy: 0.7200 - val_loss: 0.8942
# Epoch 2/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.7262 - loss: 0.7966 - val_accuracy: 0.7200 - val_loss: 0.7412
# Epoch 3/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.7912 - loss: 0.6397 - val_accuracy: 0.8300 - val_loss: 0.6069
# Epoch 4/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.8200 - loss: 0.5482 - val_accuracy: 0.8300 - val_loss: 0.5666
# Epoch 5/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8487 - loss: 0.4863 - val_accuracy: 0.8400 - val_loss: 0.5315
# Epoch 6/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8700 - loss: 0.4406 - val_accuracy: 0.8300 - val_loss: 0.5113
# Epoch 7/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8850 - loss: 0.4072 - val_accuracy: 0.8300 - val_loss: 0.4976
# Epoch 8/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8988 - loss: 0.3730 - val_accuracy: 0.8300 - val_loss: 0.4858
# Epoch 9/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.8988 - loss: 0.3502 - val_accuracy: 0.8400 - val_loss: 0.4731
# Epoch 10/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.9150 - loss: 0.3285 - val_accuracy: 0.8400 - val_loss: 0.4684
# Epoch 11/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.9175 - loss: 0.3091 - val_accuracy: 0.8500 - val_loss: 0.4783
# Epoch 12/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.9225 - loss: 0.2950 - val_accuracy: 0.8600 - val_loss: 0.4548
# Epoch 13/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.9300 - loss: 0.2828 - val_accuracy: 0.8500 - val_loss: 0.4590
# Epoch 14/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.9287 - loss: 0.2672 - val_accuracy: 0.8500 - val_loss: 0.4484
# Epoch 15/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.9375 - loss: 0.2556 - val_accuracy: 0.8600 - val_loss: 0.4462
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 180ms/step
# Fold 3 accuracy: 0.8873 | Macro F1: 0.8822
#
# --- Fold 4 / 7 ---
# Epoch 1/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.4725 - loss: 1.3279 - val_accuracy: 0.7000 - val_loss: 0.9265
# Epoch 2/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.7300 - loss: 0.7994 - val_accuracy: 0.8000 - val_loss: 0.7109
# Epoch 3/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.8112 - loss: 0.6256 - val_accuracy: 0.8000 - val_loss: 0.6254
# Epoch 4/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.8338 - loss: 0.5351 - val_accuracy: 0.7700 - val_loss: 0.5893
# Epoch 5/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.8700 - loss: 0.4745 - val_accuracy: 0.8200 - val_loss: 0.5572
# Epoch 6/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.8750 - loss: 0.4276 - val_accuracy: 0.7900 - val_loss: 0.5295
# Epoch 7/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.8838 - loss: 0.3973 - val_accuracy: 0.7900 - val_loss: 0.5224
# Epoch 8/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.8938 - loss: 0.3677 - val_accuracy: 0.8300 - val_loss: 0.5005
# Epoch 9/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.8988 - loss: 0.3461 - val_accuracy: 0.8100 - val_loss: 0.4913
# Epoch 10/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.9087 - loss: 0.3239 - val_accuracy: 0.8200 - val_loss: 0.4940
# Epoch 11/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.9187 - loss: 0.3046 - val_accuracy: 0.8300 - val_loss: 0.4841
# Epoch 12/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.9287 - loss: 0.2907 - val_accuracy: 0.8300 - val_loss: 0.4838
# Epoch 13/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.9287 - loss: 0.2771 - val_accuracy: 0.8300 - val_loss: 0.4753
# Epoch 14/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.9388 - loss: 0.2633 - val_accuracy: 0.8300 - val_loss: 0.4688
# Epoch 15/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.9350 - loss: 0.2534 - val_accuracy: 0.8300 - val_loss: 0.4654
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 184ms/step
# Fold 4 accuracy: 0.9296 | Macro F1: 0.9287
#
# --- Fold 5 / 7 ---
# Epoch 1/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - accuracy: 0.4575 - loss: 1.3332 - val_accuracy: 0.7600 - val_loss: 0.8458
# Epoch 2/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 0.7513 - loss: 0.7820 - val_accuracy: 0.8200 - val_loss: 0.6526
# Epoch 3/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8163 - loss: 0.6069 - val_accuracy: 0.8400 - val_loss: 0.5722
# Epoch 4/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - accuracy: 0.8425 - loss: 0.5187 - val_accuracy: 0.8400 - val_loss: 0.5330
# Epoch 5/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.8612 - loss: 0.4611 - val_accuracy: 0.8100 - val_loss: 0.5179
# Epoch 6/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.8763 - loss: 0.4185 - val_accuracy: 0.8200 - val_loss: 0.4897
# Epoch 7/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.8888 - loss: 0.3798 - val_accuracy: 0.8200 - val_loss: 0.4857
# Epoch 8/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.9013 - loss: 0.3562 - val_accuracy: 0.8300 - val_loss: 0.4705
# Epoch 9/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.9150 - loss: 0.3318 - val_accuracy: 0.8300 - val_loss: 0.4659
# Epoch 10/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.9162 - loss: 0.3095 - val_accuracy: 0.8300 - val_loss: 0.4632
# Epoch 11/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.9187 - loss: 0.2985 - val_accuracy: 0.8400 - val_loss: 0.4483
# Epoch 12/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.9312 - loss: 0.2818 - val_accuracy: 0.8400 - val_loss: 0.4393
# Epoch 13/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.9312 - loss: 0.2682 - val_accuracy: 0.8300 - val_loss: 0.4371
# Epoch 14/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.9425 - loss: 0.2583 - val_accuracy: 0.8100 - val_loss: 0.4391
# Epoch 15/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.9362 - loss: 0.2440 - val_accuracy: 0.8200 - val_loss: 0.4438
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 187ms/step
# Fold 5 accuracy: 0.9296 | Macro F1: 0.9242
#
# --- Fold 6 / 7 ---
# Epoch 1/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 183ms/step - accuracy: 0.4950 - loss: 1.2791 - val_accuracy: 0.6800 - val_loss: 0.8978
# Epoch 2/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.7275 - loss: 0.7975 - val_accuracy: 0.7500 - val_loss: 0.6974
# Epoch 3/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.7812 - loss: 0.6326 - val_accuracy: 0.7700 - val_loss: 0.6228
# Epoch 4/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.8325 - loss: 0.5400 - val_accuracy: 0.8100 - val_loss: 0.5701
# Epoch 5/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.8550 - loss: 0.4762 - val_accuracy: 0.8100 - val_loss: 0.5478
# Epoch 6/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.8625 - loss: 0.4354 - val_accuracy: 0.8000 - val_loss: 0.5401
# Epoch 7/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.8775 - loss: 0.4022 - val_accuracy: 0.8300 - val_loss: 0.5021
# Epoch 8/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.8888 - loss: 0.3746 - val_accuracy: 0.8400 - val_loss: 0.5016
# Epoch 9/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.8925 - loss: 0.3474 - val_accuracy: 0.8300 - val_loss: 0.4706
# Epoch 10/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.9013 - loss: 0.3263 - val_accuracy: 0.8300 - val_loss: 0.4765
# Epoch 11/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.9175 - loss: 0.3078 - val_accuracy: 0.8400 - val_loss: 0.4669
# Epoch 12/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.9125 - loss: 0.2960 - val_accuracy: 0.8400 - val_loss: 0.4690
# Epoch 13/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.9275 - loss: 0.2756 - val_accuracy: 0.8400 - val_loss: 0.4713
# Epoch 14/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.9312 - loss: 0.2663 - val_accuracy: 0.8300 - val_loss: 0.4580
# Epoch 15/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.9425 - loss: 0.2545 - val_accuracy: 0.8500 - val_loss: 0.4651
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 183ms/step
# Fold 6 accuracy: 0.9366 | Macro F1: 0.9309
#
# --- Fold 7 / 7 ---
# Epoch 1/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - accuracy: 0.4638 - loss: 1.3752 - val_accuracy: 0.6700 - val_loss: 0.9154
# Epoch 2/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.7262 - loss: 0.8282 - val_accuracy: 0.7900 - val_loss: 0.7224
# Epoch 3/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8100 - loss: 0.6504 - val_accuracy: 0.7900 - val_loss: 0.6082
# Epoch 4/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8388 - loss: 0.5521 - val_accuracy: 0.8100 - val_loss: 0.5615
# Epoch 5/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8487 - loss: 0.4897 - val_accuracy: 0.8200 - val_loss: 0.5273
# Epoch 6/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8687 - loss: 0.4411 - val_accuracy: 0.8200 - val_loss: 0.5061
# Epoch 7/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.8813 - loss: 0.4079 - val_accuracy: 0.8200 - val_loss: 0.4879
# Epoch 8/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8950 - loss: 0.3788 - val_accuracy: 0.7900 - val_loss: 0.4791
# Epoch 9/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.9000 - loss: 0.3533 - val_accuracy: 0.8100 - val_loss: 0.4677
# Epoch 10/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.9125 - loss: 0.3314 - val_accuracy: 0.8200 - val_loss: 0.4582
# Epoch 11/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.9162 - loss: 0.3116 - val_accuracy: 0.8300 - val_loss: 0.4485
# Epoch 12/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.9287 - loss: 0.2950 - val_accuracy: 0.8100 - val_loss: 0.4438
# Epoch 13/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.9275 - loss: 0.2813 - val_accuracy: 0.8300 - val_loss: 0.4420
# Epoch 14/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.9325 - loss: 0.2687 - val_accuracy: 0.8100 - val_loss: 0.4358
# Epoch 15/15
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.9413 - loss: 0.2546 - val_accuracy: 0.8200 - val_loss: 0.4423
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 183ms/step
# Fold 7 accuracy: 0.9366 | Macro F1: 0.9370
#
# --- k=7 Summary ---
# Fold     Accuracy     Macro F1
# 1        0.9085       0.9069
# 2        0.9225       0.9279
# 3        0.8873       0.8822
# 4        0.9296       0.9287
# 5        0.9296       0.9242
# 6        0.9366       0.9309
# 7        0.9366       0.9370
#
# Mean Accuracy : 0.9215  (std: 0.0166)
# Mean Macro F1 : 0.9197  (std: 0.0176)

# %% [markdown]
# Comment on the results and any differences with the previous test-train split.
# Repeat with two different values for k and comment on the results.

# %% [markdown]
# ### Comments and analysis
#
# ### Task 11 – K-Fold Cross Validation Analysis
#
# K-fold cross validation was performed with k=3, k=5, and k=7 to assess how stable the model's performance is across different train/test splits.
#
# Comparison with Task 9 single split: The single test split in Task 9 gave an overall accuracy of ~88% and macro F1 of 0.83. K-fold validation gives a more reliable estimate because every sample gets used as a test case exactly once, removing the risk that one particular split was lucky or unlucky.
#
# Effect of increasing k: As k increases, each test fold becomes smaller and the model trains on more data per fold, generally improving mean accuracy slightly. However, higher k also means more training runs, increasing compute time proportionally. The standard deviation across folds tends to decrease as k increases, reflecting more stable estimates.
#
# Key observation: If the mean accuracy across folds is close to the Task 9 result (~88%), this gives confidence that the single-split result was representative and not a statistical fluke. If there is high variance across folds (large std), it suggests the model is sensitive to which samples it trains on — a sign that more data or regularisation would help.

# %% [markdown]
# ## Task 12
# With the best learning rate that you found in the previous task, add a non-zero momentum to the training with the SGD optimizer (consider 3 values for the momentum). Report on how your results change.

# %%
# 3 Different Momentum Values
momentums = [0.3, 0.6, 0.9]
histories = {}

for m in momentums:
    print(f"\n--- Training with momentum = {m} ---")

    # Create new model each time
    fresh_model = create_fresh_model()

    # Train
    params = (0.1, m, False)   # (learning_rate, momentum, nesterov)
    _, h = transfer_learning(train_set, eval_set, fresh_model, epoch, params)
    histories[m] = h


# Plot Loss
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
fig.suptitle('Task 12: Transfer Learning – Effect of Momentum', fontsize=14)

for m in momentums:
    axes[0].plot(histories[m].history['loss'],     label=f'Train m={m}')
    axes[0].plot(histories[m].history['val_loss'], label=f'Val   m={m}', linestyle='--')

axes[0].set_title('Validation Loss vs Epoch')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].legend(fontsize=8)
axes[0].grid(True, alpha=0.3)


# Plot Accuracy
for m in momentums:
    axes[1].plot(histories[m].history['accuracy'],     label=f'Train m={m}')
    axes[1].plot(histories[m].history['val_accuracy'], label=f'Val   m={m}', linestyle='--')

axes[1].set_title('Validation Accuracy vs Epoch')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy')
axes[1].legend(fontsize=8)
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('task12_momentum_values.png', dpi=150, bbox_inches='tight')
plt.show()


# Print final validation accuracy for each so you can identify the best
print("\nFinal validation accuracies:")
for m in momentums:
    final_acc = histories[m].history['val_accuracy'][-1]
    print(f"  momentum={m}: {final_acc:.4f}")

# Store the best momentum for later tasks
best_momentum = max(momentums, key=lambda m: histories[m].history['val_accuracy'][-1])
print(f"\nBest momentum: {best_momentum}")
# Out:
# --- Training with momentum = 0.3 ---
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 172ms/step - accuracy: 0.5888 - loss: 2.6262 - val_accuracy: 0.8000 - val_loss: 0.7436
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.8225 - loss: 0.5754 - val_accuracy: 0.8000 - val_loss: 0.6143
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.9175 - loss: 0.2804 - val_accuracy: 0.7900 - val_loss: 0.5657
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.9538 - loss: 0.1412 - val_accuracy: 0.7700 - val_loss: 0.5751
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.9575 - loss: 0.1237 - val_accuracy: 0.8400 - val_loss: 0.5358
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.9800 - loss: 0.0746 - val_accuracy: 0.8200 - val_loss: 0.5045
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.9912 - loss: 0.0478 - val_accuracy: 0.8500 - val_loss: 0.5354
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 1.0000 - loss: 0.0342 - val_accuracy: 0.8200 - val_loss: 0.5248
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.9962 - loss: 0.0333 - val_accuracy: 0.8400 - val_loss: 0.5496
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 1.0000 - loss: 0.0275 - val_accuracy: 0.8400 - val_loss: 0.5485
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 1.0000 - loss: 0.0242 - val_accuracy: 0.8300 - val_loss: 0.5703
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 1.0000 - loss: 0.0226 - val_accuracy: 0.8600 - val_loss: 0.5495
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 1.0000 - loss: 0.0212 - val_accuracy: 0.8300 - val_loss: 0.5559
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 1.0000 - loss: 0.0195 - val_accuracy: 0.8200 - val_loss: 0.5583
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 1.0000 - loss: 0.0183 - val_accuracy: 0.8500 - val_loss: 0.5499
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 1.0000 - loss: 0.0173 - val_accuracy: 0.8400 - val_loss: 0.5575
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 1.0000 - loss: 0.0162 - val_accuracy: 0.8400 - val_loss: 0.5517
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 1.0000 - loss: 0.0155 - val_accuracy: 0.8400 - val_loss: 0.5506
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 1.0000 - loss: 0.0146 - val_accuracy: 0.8400 - val_loss: 0.5589
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 1.0000 - loss: 0.0140 - val_accuracy: 0.8300 - val_loss: 0.5687
#
# --- Training with momentum = 0.6 ---
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 170ms/step - accuracy: 0.6100 - loss: 2.7451 - val_accuracy: 0.7600 - val_loss: 1.1521
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.8625 - loss: 0.4936 - val_accuracy: 0.7400 - val_loss: 1.2262
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.9175 - loss: 0.2838 - val_accuracy: 0.7800 - val_loss: 1.0399
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.9575 - loss: 0.1240 - val_accuracy: 0.8200 - val_loss: 0.6761
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.9750 - loss: 0.0739 - val_accuracy: 0.8600 - val_loss: 0.6420
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.9950 - loss: 0.0265 - val_accuracy: 0.8300 - val_loss: 0.6655
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 0.9987 - loss: 0.0160 - val_accuracy: 0.8500 - val_loss: 0.5755
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 1.0000 - loss: 0.0130 - val_accuracy: 0.8500 - val_loss: 0.5862
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 1.0000 - loss: 0.0106 - val_accuracy: 0.8500 - val_loss: 0.5850
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 1.0000 - loss: 0.0097 - val_accuracy: 0.8600 - val_loss: 0.6062
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.8500 - val_loss: 0.6133
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.8500 - val_loss: 0.6229
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 0.8600 - val_loss: 0.6118
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 0.8500 - val_loss: 0.6149
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.8500 - val_loss: 0.6105
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.8500 - val_loss: 0.6118
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.8600 - val_loss: 0.6240
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.8500 - val_loss: 0.6177
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.8600 - val_loss: 0.6240
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.8600 - val_loss: 0.6232
#
# --- Training with momentum = 0.9 ---
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - accuracy: 0.5537 - loss: 7.4765 - val_accuracy: 0.8300 - val_loss: 4.1852
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.8413 - loss: 2.8532 - val_accuracy: 0.7900 - val_loss: 4.3573
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.9087 - loss: 1.1527 - val_accuracy: 0.8800 - val_loss: 2.3131
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.9337 - loss: 0.6809 - val_accuracy: 0.8200 - val_loss: 2.7441
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.9275 - loss: 0.7693 - val_accuracy: 0.8400 - val_loss: 3.1868
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.9675 - loss: 0.2643 - val_accuracy: 0.8300 - val_loss: 3.1385
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.9725 - loss: 0.1328 - val_accuracy: 0.8500 - val_loss: 2.4114
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.9937 - loss: 0.0439 - val_accuracy: 0.8400 - val_loss: 2.5614
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.9987 - loss: 0.0015 - val_accuracy: 0.8700 - val_loss: 2.4380
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.9962 - loss: 0.0125 - val_accuracy: 0.8600 - val_loss: 2.5003
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.9975 - loss: 0.0029 - val_accuracy: 0.8600 - val_loss: 2.6089
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.9975 - loss: 0.0110 - val_accuracy: 0.8500 - val_loss: 2.5627
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.9987 - loss: 0.0037 - val_accuracy: 0.8700 - val_loss: 2.4422
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 1.0000 - loss: 1.3063e-04 - val_accuracy: 0.8700 - val_loss: 2.4365
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 1.0000 - loss: 4.8915e-05 - val_accuracy: 0.8700 - val_loss: 2.4358
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 1.0000 - loss: 3.5084e-05 - val_accuracy: 0.8700 - val_loss: 2.4354
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 1.0000 - loss: 3.0106e-05 - val_accuracy: 0.8700 - val_loss: 2.4358
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 1.0000 - loss: 2.6958e-05 - val_accuracy: 0.8700 - val_loss: 2.4365
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 1.0000 - loss: 2.4265e-05 - val_accuracy: 0.8600 - val_loss: 2.4373
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 1.0000 - loss: 2.2619e-05 - val_accuracy: 0.8600 - val_loss: 2.4379
# Final validation accuracies:
#   momentum=0.3: 0.8300
#   momentum=0.6: 0.8600
#   momentum=0.9: 0.8600
#
# Best momentum: 0.6

# %% [markdown]
# ### Report
#
# All three momentum settings show a clear plateau in performance between epochs 10 and 12, with training loss approaching zero while validation loss remains higher. This divergence indicates that the models begin to overfit once they have fully memorised the training data. The run with momentum = 0.9 displays noticeably unstable behaviour: validation accuracy peaks early and then deteriorates, and validation loss increases after roughly five epochs. This suggests that a high momentum value may be causing the optimiser to overshoot minima, leading to poorer generalisation. In contrast, momentum values of 0.3 and 0.6 produce more stable and comparable learning curves. Both achieve similar final accuracy, although momentum = 0.3 converges slightly faster, reaching its peak performance earlier in training.

# %% [markdown]
# ## Task 13
# Now using “accelerated transfer learning”, repeat the training process (k-fold validation is optional this time). You should prepare your training, validation and test sets based on {(F(x1).t1), (F(x2),t2),...,(F(xm),tm)}, and re-do Task 12.

# %%
# Build feature extractor for accelerated learning
feature_extractor = tf.keras.applications.MobileNetV2(
    weights='imagenet',
    include_top=False,
    pooling='avg',
    input_shape=(224, 224, 3)
)
feature_extractor.trainable = False

# Dat
F_train = feature_extractor.predict(final_train[0], batch_size=32)
F_val   = feature_extractor.predict(final_val[0],   batch_size=32)
F_test  = feature_extractor.predict(final_test[0],  batch_size=32)

# Labels 
y_train = final_train[1]
y_val   = final_val[1]
y_test  = final_test[1]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 183ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step

# %%
def create_accelerated_model(lr, momentum):
    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(1280,)),
        tf.keras.layers.Dense(5, activation='softmax')
    ])

    opt = tf.keras.optimizers.SGD(
        learning_rate=lr,
        momentum=momentum,
        nesterov=False
    )

    model.compile(
        optimizer=opt,
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %%
import time
momentums = [0.3, 0.6, 0.9]
histories = {}
test_accuracies = {}
times = {}

for m in momentums:
    print(f"\n--- Training accelerated model with momentum = {m} ---")

    model = create_accelerated_model(best_lr, m)

    start = time.time()

    history = model.fit(
        F_train, y_train,
        validation_data=(F_val, y_val),
        epochs=20,
        batch_size=32,
        verbose=1
    )

    end = time.time()
    times[m] = end - start
    histories[m] = history

    # Evaluate on test set
    y_prob = model.predict(F_test)
    y_pred = np.argmax(y_prob, axis=1)
    acc = np.mean(y_pred == y_test)
    test_accuracies[m] = acc

    print(f"Momentum {m} → Test Accuracy: {acc:.4f} | Time: {times[m]:.2f} sec")
# Out:
# --- Training accelerated model with momentum = 0.3 ---
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5450 - loss: 1.1848 - val_accuracy: 0.7200 - val_loss: 0.8579
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 786us/step - accuracy: 0.7875 - loss: 0.6618 - val_accuracy: 0.7700 - val_loss: 0.6742
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - accuracy: 0.8325 - loss: 0.5226 - val_accuracy: 0.8100 - val_loss: 0.6012
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - accuracy: 0.8612 - loss: 0.4481 - val_accuracy: 0.7900 - val_loss: 0.5436
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - accuracy: 0.8938 - loss: 0.3902 - val_accuracy: 0.8100 - val_loss: 0.5204
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - accuracy: 0.9100 - loss: 0.3527 - val_accuracy: 0.8300 - val_loss: 0.4916
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - accuracy: 0.9175 - loss: 0.3199 - val_accuracy: 0.8200 - val_loss: 0.4986
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.9237 - loss: 0.2974 - val_accuracy: 0.8400 - val_loss: 0.4782
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - accuracy: 0.9300 - loss: 0.2754 - val_accuracy: 0.8200 - val_loss: 0.4609
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - accuracy: 0.9388 - loss: 0.2567 - val_accuracy: 0.8100 - val_loss: 0.4754
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step - accuracy: 0.9438 - loss: 0.2435 - val_accuracy: 0.7900 - val_loss: 0.4584
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 808us/step - accuracy: 0.9538 - loss: 0.2317 - val_accuracy: 0.8200 - val_loss: 0.4542
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step - accuracy: 0.9550 - loss: 0.2172 - val_accuracy: 0.8200 - val_loss: 0.4480
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - accuracy: 0.9625 - loss: 0.2067 - val_accuracy: 0.8300 - val_loss: 0.4589
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step - accuracy: 0.9675 - loss: 0.1971 - val_accuracy: 0.8300 - val_loss: 0.4443
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 810us/step - accuracy: 0.9700 - loss: 0.1863 - val_accuracy: 0.8100 - val_loss: 0.4505
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step - accuracy: 0.9712 - loss: 0.1797 - val_accuracy: 0.8300 - val_loss: 0.4435
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - accuracy: 0.9712 - loss: 0.1704 - val_accuracy: 0.8500 - val_loss: 0.4291
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.9737 - loss: 0.1675 - val_accuracy: 0.8200 - val_loss: 0.4388
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step - accuracy: 0.9775 - loss: 0.1570 - val_accuracy: 0.8400 - val_loss: 0.4310
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Momentum 0.3 → Test Accuracy: 0.8500 | Time: 0.64 sec
#
# --- Training accelerated model with momentum = 0.6 ---
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5888 - loss: 1.0986 - val_accuracy: 0.7900 - val_loss: 0.6340
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - accuracy: 0.8213 - loss: 0.5500 - val_accuracy: 0.7900 - val_loss: 0.5454
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step - accuracy: 0.8825 - loss: 0.4234 - val_accuracy: 0.8300 - val_loss: 0.4942
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step - accuracy: 0.8950 - loss: 0.3472 - val_accuracy: 0.8200 - val_loss: 0.4850
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step - accuracy: 0.9175 - loss: 0.3033 - val_accuracy: 0.8100 - val_loss: 0.4512
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step - accuracy: 0.9300 - loss: 0.2688 - val_accuracy: 0.8300 - val_loss: 0.4457
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - accuracy: 0.9362 - loss: 0.2432 - val_accuracy: 0.8300 - val_loss: 0.4355
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step - accuracy: 0.9525 - loss: 0.2174 - val_accuracy: 0.8300 - val_loss: 0.4411
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - accuracy: 0.9625 - loss: 0.1985 - val_accuracy: 0.8400 - val_loss: 0.4316
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 810us/step - accuracy: 0.9650 - loss: 0.1827 - val_accuracy: 0.8400 - val_loss: 0.4216
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step - accuracy: 0.9625 - loss: 0.1731 - val_accuracy: 0.8400 - val_loss: 0.4297
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - accuracy: 0.9725 - loss: 0.1569 - val_accuracy: 0.8400 - val_loss: 0.4280
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step - accuracy: 0.9762 - loss: 0.1467 - val_accuracy: 0.8500 - val_loss: 0.4424
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step - accuracy: 0.9800 - loss: 0.1397 - val_accuracy: 0.8300 - val_loss: 0.4289
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - accuracy: 0.9775 - loss: 0.1315 - val_accuracy: 0.8400 - val_loss: 0.4298
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - accuracy: 0.9812 - loss: 0.1246 - val_accuracy: 0.8500 - val_loss: 0.4447
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step - accuracy: 0.9825 - loss: 0.1175 - val_accuracy: 0.8600 - val_loss: 0.4418
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step - accuracy: 0.9925 - loss: 0.1112 - val_accuracy: 0.8400 - val_loss: 0.4312
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - accuracy: 0.9900 - loss: 0.1060 - val_accuracy: 0.8400 - val_loss: 0.4373
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step - accuracy: 0.9900 - loss: 0.1023 - val_accuracy: 0.8500 - val_loss: 0.4322
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Momentum 0.6 → Test Accuracy: 0.8500 | Time: 0.63 sec
#
# --- Training accelerated model with momentum = 0.9 ---
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6162 - loss: 0.9702 - val_accuracy: 0.8200 - val_loss: 0.5610
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8963 - loss: 0.3078 - val_accuracy: 0.8000 - val_loss: 0.5616
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step - accuracy: 0.9325 - loss: 0.2100 - val_accuracy: 0.8500 - val_loss: 0.4485
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - accuracy: 0.9638 - loss: 0.1419 - val_accuracy: 0.8100 - val_loss: 0.4847
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 807us/step - accuracy: 0.9762 - loss: 0.1111 - val_accuracy: 0.8600 - val_loss: 0.4681
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step - accuracy: 0.9887 - loss: 0.0830 - val_accuracy: 0.8400 - val_loss: 0.4776
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step - accuracy: 0.9912 - loss: 0.0731 - val_accuracy: 0.8700 - val_loss: 0.4612
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step - accuracy: 0.9937 - loss: 0.0621 - val_accuracy: 0.8600 - val_loss: 0.4934
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step - accuracy: 0.9987 - loss: 0.0532 - val_accuracy: 0.8600 - val_loss: 0.4799
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - accuracy: 1.0000 - loss: 0.0475 - val_accuracy: 0.8600 - val_loss: 0.4809
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step - accuracy: 1.0000 - loss: 0.0445 - val_accuracy: 0.8600 - val_loss: 0.4916
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - accuracy: 1.0000 - loss: 0.0414 - val_accuracy: 0.8600 - val_loss: 0.5045
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step - accuracy: 1.0000 - loss: 0.0365 - val_accuracy: 0.8500 - val_loss: 0.4876
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step - accuracy: 1.0000 - loss: 0.0335 - val_accuracy: 0.8700 - val_loss: 0.4708
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step - accuracy: 1.0000 - loss: 0.0328 - val_accuracy: 0.8500 - val_loss: 0.4924
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - accuracy: 1.0000 - loss: 0.0286 - val_accuracy: 0.8600 - val_loss: 0.4748
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step - accuracy: 1.0000 - loss: 0.0272 - val_accuracy: 0.8600 - val_loss: 0.4815
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - accuracy: 1.0000 - loss: 0.0260 - val_accuracy: 0.8700 - val_loss: 0.4836
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step - accuracy: 1.0000 - loss: 0.0250 - val_accuracy: 0.8600 - val_loss: 0.4804
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step - accuracy: 1.0000 - loss: 0.0236 - val_accuracy: 0.8600 - val_loss: 0.4850
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Momentum 0.9 → Test Accuracy: 0.8500 | Time: 0.65 sec

# %% [markdown]
# Plot and comment on the results and differences against the standard implementation of transfer learning.

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
fig.suptitle('Accelerated Transfer Learning – Effect of Momentum', fontsize=14)

# Loss
for m in momentums:
    axes[0].plot(histories[m].history['loss'],     label=f'Train m={m}')
    axes[0].plot(histories[m].history['val_loss'], label=f'Val m={m}', linestyle='--')

axes[0].set_title('Loss vs Epoch')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].legend(fontsize=8)
axes[0].grid(True, alpha=0.3)

# Accuracy
for m in momentums:
    axes[1].plot(histories[m].history['accuracy'],     label=f'Train m={m}')
    axes[1].plot(histories[m].history['val_accuracy'], label=f'Val m={m}', linestyle='--')

axes[1].set_title('Accuracy vs Epoch')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy')
axes[1].legend(fontsize=8)
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Your Comments:
#
# The accelerated transfer learning approach trained substantially faster than the standard implementation, completing all 45 epochs in only a few seconds. Across all three momentum values, training accuracy reached its peak by epoch 6, compared with epoch 8 in the standard model, indicating quicker convergence when training only the classifier head. Initial training loss was also consistently lower than in the standard setup, and the validation loss curves for momentum 0.3 and 0.6 were almost perfectly flat, showing far greater stability than the fluctuations observed previously.
#
# However, a momentum of 0.9 behaved noticeably differently. In the accelerated setting, it produced more erratic validation accuracy and loss, and even reached a higher peak loss (~2.5) compared with the standard model (~1.5). This suggests that high momentum may overshoot even when training a lightweight classifier. Overall, while accelerated transfer learning is dramatically faster and generally more stable, the accuracy curves are less smooth than those from standard transfer learning, reflecting the reduced capacity of the classifier and its greater sensitivity to optimisation noise.

# %% [markdown]
# ## Task 14
# Use the results of all experiments to make suggestions for future work and recommendations for parameter values to anyone else who may be interested in a similar implementation of transfer learning.

# %% [markdown]
# ### Your answer:

# %% [markdown]
# Based on the outcomes of all experiments, accelerated transfer learning is the most practical starting point for anyone working with a similar dataset. It trains in only a few seconds, reaches peak accuracy earlier than the standard approach, and avoids the heavy overfitting observed when fine-tuning the full MobileNetV2 model. This makes it well suited to scenarios where computational resources or time are limited.
#
# Early stopping should be included in any future implementation, as the standard transfer learning showed clear divergence between training and validation loss after only a few epochs. Without early stopping, the model continues to memorise the training data without any meaningful improvement in generalisation. Early stopping with retaining best weights would ensure the optimal model is retained regardless of when training is stopped.
#
# In terms of optimiser settings, a momentum value of 0.3 is recommended as it consistently reached peak performance quickly and behaved more reliably than higher values. Higher momentum values such as 0.9 introduced instability.
#
# A learning rate of 0.1 produced the strongest results across the experiments and is recommended as the default starting point. Rreducing the rate with a larger epoch number could be an alternative given its more stable train/validation results during testing.
#
# For future work, introducing regularisation techniques such as dropout or L2 weight decay could reduce the overfitting associated with the higher learning rate and could push validation accuracy further.
#
# Data augmentation is also possible for future work, especially as this data set is relatively small, as it increases the amounnt of training data available.
#
# Learning rate scheduling, such as cosine decay or step decay, could also allow the model to converge quickly in early epochs while making finer adjustments later, potentially combining the convergence speed of lr=0.1 with the stability of lr=0.01.
#
# Overall, these settings provide a solid foundation for stable, efficient, and accurate transfer learning on datasets of this scale.

# %% [markdown]
# ### 15 Groupwork : 	Describe	the	breakdown	of	the	specific	contributions	of	each	team	member	to	the
# project.

# %% [markdown]
# Rather than dividing the project into fixed individual responsibilities, the team adopted a collaborative approach where all members actively engaged with every aspect of the work. Each team member wanted to develop a full understanding of transfer learning. As a result, all members contributed to the implementation, debugging, and analysis of each task throughout the project.
#
# This meant that tasks were worked through together, with members cross-checking each other's code, discussing results, and jointly interpreting the outputs of each experiment. This ensured that all members had a good understanding of the project and its implementation.
#
# This approach is justified as an effective groupwork strategy for a learning-focused project. Having shared ownership means every member understands each section. This approach is obviously less time-efficient than with task division, however for the purposes of this project the educational benefit of full participation outweighed that concern
